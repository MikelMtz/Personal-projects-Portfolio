# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np

Shifted_Force_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_1um.csv', names=['Force'])
Shifted_Force_1800nm_1um = Shifted_Force_1800nm_1um.values.tolist()
Shifted_Force_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_3um.csv', names=['Force'])
Shifted_Force_1800nm_3um = Shifted_Force_1800nm_3um.values.tolist()
Shifted_Force_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_5um.csv', names=['Force'])
Shifted_Force_1800nm_5um = Shifted_Force_1800nm_5um.values.tolist()
Shifted_Force_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_7um.csv', names=['Force'])
Shifted_Force_1800nm_7um = Shifted_Force_1800nm_7um.values.tolist()
Shifted_Force_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_10um.csv', names=['Force'])
Shifted_Force_1800nm_10um = Shifted_Force_1800nm_10um.values.tolist()
Shifted_Force_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_15um.csv', names=['Force'])
Shifted_Force_1800nm_15um = Shifted_Force_1800nm_15um.values.tolist()
Shifted_Force_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_20um.csv', names=['Force'])
Shifted_Force_1800nm_20um = Shifted_Force_1800nm_20um.values.tolist()
Shifted_Force_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_500nm.csv', names=['Force'])
Shifted_Force_1800nm_500nm = Shifted_Force_1800nm_500nm.values.tolist()
Shifted_Force_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_800nm.csv', names=['Force'])
Shifted_Force_1800nm_800nm = Shifted_Force_1800nm_800nm.values.tolist()


d_final_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_1um.csv', names=['Force'])
d_final_1800nm_1um = d_final_1800nm_1um.values.tolist()
d_final_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_3um.csv', names=['Force'])
d_final_1800nm_3um = d_final_1800nm_3um.values.tolist()
#d_final_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_5um.csv', names=['Force'])
#d_final_1800nm_5um = d_final_1800nm_5um.values.tolist()
d_final_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_7um.csv', names=['Force'])
d_final_1800nm_7um = d_final_1800nm_7um.values.tolist()
d_final_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_10um.csv', names=['Force'])
d_final_1800nm_10um = d_final_1800nm_10um.values.tolist()
d_final_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_15um.csv', names=['Force'])
d_final_1800nm_15um = d_final_1800nm_15um.values.tolist()
d_final_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_20um.csv', names=['Force'])
d_final_1800nm_20um = d_final_1800nm_20um.values.tolist()
d_final_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_500nm.csv', names=['Force'])
d_final_1800nm_500nm = d_final_1800nm_500nm.values.tolist()
d_final_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_800nm.csv', names=['Force'])
d_final_1800nm_800nm = d_final_1800nm_800nm.values.tolist()

r = 10**-6 #radius of sphere
n = 0.0011439 #viscosity in Pa/s, for 20 degrees celcius
d = np.linspace(0,2000,20000)
def Hydro_forces(v,d,r,n):
    return (v*6*math.pi*r**2*n)*10**12/(d*10**-9)

list = ('1um', '3um', '5um', '7um', '10um', '15um', '20um', '500nm', '800nm')
plt.title("Au vs BSG (Force in nN, then x1000 for pN)")
plt.plot(d_final_1800nm_1um, Shifted_Force_1800nm_1um, label='1um')
plt.plot(d_final_1800nm_3um, Shifted_Force_1800nm_3um, label='3um')
#plt.plot(d_final_1800nm_5um, Shifted_Force_1800nm_5um, label='5um')
plt.plot(d_final_1800nm_7um, Shifted_Force_1800nm_7um, label='7um')
plt.plot(d_final_1800nm_10um, Shifted_Force_1800nm_10um, label='10um')
plt.plot(d_final_1800nm_15um, Shifted_Force_1800nm_15um, label='15um')
plt.plot(d_final_1800nm_20um, Shifted_Force_1800nm_20um, label='20um')
plt.plot(d_final_1800nm_500nm, Shifted_Force_1800nm_500nm, label='500nm')
plt.plot(d_final_1800nm_800nm, Shifted_Force_1800nm_800nm, label='800nm')
#for velocities in (1*10**-6,3*10**-6,5*10**-6,7*10**-6,10*10**-6,15*10**-6,20*10**-6,0.5*10**-6,0.8*10**-6):
#   plt.scatter(d, Hydro_forces(velocities,d,r,n), c='red', s=0.5)
plt.xlabel("Separation (nm)")
plt.ylabel("Force (nN)")
plt.legend()
plt.grid()
plt.xlim(0, 500)
plt.ylim(-0.5,4)
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
r = 10**-6 #radius of sphere
n = 0.0011439 #viscosity in Pa/s, for 20 degrees celcius
d = np.linspace(0,2000,20000)
xlim = (0,200)
ylim = (-0.5,4)

figure, ax = plt.subplots(3, 3,figsize=(15, 15)) 

figure.suptitle('Position 1', fontsize=20)


ax[0,0].plot(d_final_1800nm_1um, Shifted_Force_1800nm_1um, label='1um')
ax[0,0].set_title("Au vs BSG for 1um/s")
ax[0,0].scatter(d, Hydro_forces(1*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[0,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,0].legend()
ax[0,0].grid()
ax[0,0].set_xlim(xlim)
ax[0,0].set_ylim(ylim)

ax[0,1].plot(d_final_1800nm_3um, Shifted_Force_1800nm_3um, label='3um')
ax[0,1].set_title("Au vs BSG for 3um/s")
ax[0,1].scatter(d, Hydro_forces(3*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[0,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,1].legend()
ax[0,1].grid()
ax[0,1].set_xlim(xlim)
ax[0,1].set_ylim(ylim)

#ax[0,2].plot(d_final_1800nm_5um, Shifted_Force_1800nm_5um, label='5um')
#ax[0,2].set_title("Au vs BSG for 5um/s")
#ax[0,2].scatter(d, Hydro_forces(5*10**-6,d,r,n), c='red', s=0.5, label='clasical')
#ax[0,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
#ax[0,2].legend()
#ax[0,2].grid()
#ax[0,2].set_xlim(xlim)
#ax[0,2].set_ylim(ylim)

ax[1,0].plot(d_final_1800nm_7um, Shifted_Force_1800nm_7um, label='7um')
ax[1,0].set_title("Au vs BSG for 7um/s")
ax[1,0].scatter(d, Hydro_forces(7*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,0].legend()
ax[1,0].grid()
ax[1,0].set_xlim(xlim)
ax[1,0].set_ylim(ylim)

ax[1,1].plot(d_final_1800nm_10um, Shifted_Force_1800nm_10um, label='10um')
ax[1,1].set_title("Au vs BSG for 10um/s")
ax[1,1].scatter(d, Hydro_forces(10*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,1].legend()
ax[1,1].grid()
ax[1,1].set_xlim(xlim)
ax[1,1].set_ylim(ylim)

ax[1,2].plot(d_final_1800nm_15um, Shifted_Force_1800nm_15um, label='15um')
ax[1,2].set_title("Au vs BSG for 15um/s")
ax[1,2].scatter(d, Hydro_forces(15*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,2].legend()
ax[1,2].grid()
ax[1,2].set_xlim(xlim)
ax[1,2].set_ylim(ylim)

ax[2,0].plot(d_final_1800nm_20um, Shifted_Force_1800nm_20um, label='20um')
ax[2,0].set_title("Au vs BSG for 20um/s")
ax[2,0].scatter(d, Hydro_forces(20*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,0].legend()
ax[2,0].grid()
ax[2,0].set_xlim(xlim)
ax[2,0].set_ylim(ylim)

ax[2,1].plot(d_final_1800nm_500nm, Shifted_Force_1800nm_500nm, label='500nm')
ax[2,1].set_title("Au vs BSG for 500nm/s")
ax[2,1].scatter(d, Hydro_forces(0.5*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,1].legend()
ax[2,1].grid()
ax[2,1].set_xlim(xlim)
ax[2,1].set_ylim(ylim)

ax[2,2].plot(d_final_1800nm_800nm, Shifted_Force_1800nm_800nm, label='800nm')
ax[2,2].set_title("Au vs BSG for 800nm/s")
ax[2,2].scatter(d, Hydro_forces(0.8*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,2].legend()
ax[2,2].grid()
ax[2,2].set_xlim(xlim)
ax[2,2].set_ylim(ylim)

plt.show()
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_41524\562066659.py:49: RuntimeWarning: divide by zero encountered in divide
#   return (v*6*math.pi*r**2*n)*10**12/(d*10**-9)
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
