# %%
import matplotlib.pyplot as plt

f=open(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Making final plots\Au plate distrib.txt',"r")
lines=f.readlines()
a=[]
b=[]
for x in lines:
    a.append(x.split(' ')[0])
f.close()
for x in lines:
    b.append(x.split(' ')[2])
f.close()
x_values=[]
y_values=[]
for t in range(len(a)):
    x_values.append(float(a[t])*10**9)
for t in range(len(b)):
    y_values.append(float(b[t])*10**(-6))
print(x_values)
print(y_values)
plt.scatter(x_values[0:223],y_values[0:223],marker='+',s=70,color='green')
plt.xlabel("Height (nm)", fontsize='12')
plt.ylabel(r'$\rho (\mu m^{-1})$', fontsize='12')
plt.title("gold plate")
plt.show()

f=open(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Making final plots\Au sphere distrib.txt',"r")
lines=f.readlines()
a=[]
b=[]
for x in lines:
    a.append(x.split(' ')[0])
f.close()
for x in lines:
    b.append(x.split(' ')[2])
f.close()
x_values=[]
y_values=[]
for t in range(len(a)):
    x_values.append(float(a[t])*10**9)
for t in range(len(b)):
    y_values.append(float(b[t])*10**(-6))
print(x_values)
print(y_values)
plt.scatter(x_values[0:223],y_values[0:223],marker='+',s=70,color='r')
plt.xlabel("Height (nm)", fontsize='12')
plt.ylabel(r'$\rho (\mu m^{-1})$', fontsize='12')
plt.title("gold sphere")
plt.show()

f=open(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Making final plots\BSG sphere distrib.txt',"r")
lines=f.readlines()
a=[]
b=[]
for x in lines:
    a.append(x.split(' ')[0])
f.close()
for x in lines:
    b.append(x.split(' ')[2])
f.close()
x_values=[]
y_values=[]
for t in range(len(a)):
    x_values.append(float(a[t])*10**9)
for t in range(len(b)):
    y_values.append(float(b[t])*10**(-6))
print(x_values)
print(y_values)
plt.scatter(x_values[0:223],y_values[0:223],marker='+',s=70,color='r')
plt.xlabel("Height (nm)", fontsize='12')
plt.ylabel(r'$\rho (\mu m^{-1})$', fontsize='12')
plt.title("BSG sphere")
plt.show()

f=open(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Making final plots\Si plate distrib.txt',"r")
lines=f.readlines()
a=[]
b=[]
for x in lines:
    a.append(x.split(' ')[0])
f.close()
for x in lines:
    b.append(x.split(' ')[2])
f.close()
x_values=[]
y_values=[]
for t in range(len(a)):
    x_values.append(float(a[t])*10**9)
for t in range(len(b)):
    y_values.append(float(b[t])*10**(-9))
print(x_values)
print(y_values)
plt.scatter(x_values[0:223],y_values[0:223],marker='+',s=70,color='green')
plt.xlabel("Height (nm)", fontsize='12')
plt.ylabel(r'$\rho (nm^{-1})$', fontsize='12')
plt.title("Si plate")
plt.show()
# Out:
# [-20.532139, -20.330576999999998, -20.129016, -19.927454, -19.725891999999998, -19.524331, -19.322769, -19.121208, -18.919646, -18.718084, -18.516523, -18.314961, -18.1134, -17.911838, -17.710277, -17.508715, -17.307153, -17.105592, -16.90403, -16.702469, -16.500907, -16.299346, -16.097784, -15.896222, -15.694661, -15.493099, -15.291538000000001, -15.089976, -14.888414000000001, -14.686853000000001, -14.485291, -14.28373, -14.082168000000001, -13.880607000000001, -13.679045, -13.477483000000001, -13.275922, -13.07436, -12.872798999999999, -12.671237, -12.469675, -12.268113999999999, -12.066552, -11.864991, -11.663428999999999, -11.461867999999999, -11.260306, -11.058743999999999, -10.857183, -10.655621, -10.45406, -10.252498, -10.050936, -9.849374899999999, -9.6478133, -9.4462517, -9.2446901, -9.0431286, -8.841567, -8.6400054, -8.4384438, -8.2368822, -8.0353206, -7.8337591, -7.6321975, -7.4306359, -7.229074300000001, -7.0275127, -6.8259512, -6.624389600000001, -6.422828, -6.221266399
# ...
