# %%
import statistics
import matplotlib.pyplot as plt
import pandas
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

S=[]
with open(r'c:\Users\mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\D.txt', 'r') as f:
    for line in f:
        d = line.split()
        d = d[0]
        S.append(d)

separation = S[1:len(S)]

# %%
#1um/s
Mean_1800nm_1um = []
for i in range(8704):   
    data=[]
    for files in range(1,8):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\1um.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_1um.append(statistics.mean(data))        

#3um/s
Mean_1800nm_3um = []
for i in range(8704):   
    data=[]
    for files in range(1,11):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\3um.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_3um.append(statistics.mean(data))

#5um/s
Mean_1800nm_5um = []
for i in range(8704):   
    data=[]
    for files in range(1,9):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\5um.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_5um.append(statistics.mean(data))                      

#7um/s
Mean_1800nm_7um = []
for i in range(8704):   
    data=[]
    for files in range(1,7):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\7um.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_7um.append(statistics.mean(data))

#10um/s
Mean_1800nm_10um = []
for i in range(8704):   
    data=[]
    for files in range(1,11):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\10um.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_10um.append(statistics.mean(data))

#15um/s
Mean_1800nm_15um = []
for i in range(8704):   
    data=[]
    for files in range(1,11):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\15um.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_15um.append(statistics.mean(data))

#20um/s
Mean_1800nm_20um = []
for i in range(8704):   
    data=[]
    for files in range(1,9):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\20um.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_20um.append(statistics.mean(data))

#500nm/s
Mean_1800nm_500nm = []
for i in range(8704):   
    data=[]
    for files in range(1,11):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\500nm.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_500nm.append(statistics.mean(data))

#800nm/s
Mean_1800nm_800nm = []
for i in range(8704):   
    data=[]
    for files in range(1,8):
        S1=[]
        with open(fr'c:\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\800nm.s\{files}.spm.txt', 'r') as f:
            for line in f:
                d = line.split()
                d = d[0]
                S1.append(d)

        data.append(float(S1[1:len(S1)][i])) 

    Mean_1800nm_800nm.append(statistics.mean(data))

# %%
#Average

Force_1800nm_1um=[]
for i in range(8704):
    y = Mean_1800nm_1um[i]*0.22
    Force_1800nm_1um.append(y)
Force_1800nm_3um=[]
for i in range(8704):
    y = Mean_1800nm_3um[i]*0.22
    Force_1800nm_3um.append(y)
Force_1800nm_5um=[]
for i in range(8704):
    y = Mean_1800nm_5um[i]*0.22
    Force_1800nm_5um.append(y)
Force_1800nm_7um=[]
for i in range(8704):
    y = Mean_1800nm_7um[i]*0.22
    Force_1800nm_7um.append(y)
Force_1800nm_10um=[]
for i in range(8704):
    y = Mean_1800nm_10um[i]*0.22
    Force_1800nm_10um.append(y)
Force_1800nm_15um=[]
for i in range(8704):
    y = Mean_1800nm_15um[i]*0.22
    Force_1800nm_15um.append(y)
Force_1800nm_20um=[]
for i in range(8704):
    y = Mean_1800nm_20um[i]*0.22
    Force_1800nm_20um.append(y)
Force_1800nm_500nm=[]
for i in range(8704):
    y = Mean_1800nm_500nm[i]*0.22
    Force_1800nm_500nm.append(y)
Force_1800nm_800nm=[]
for i in range(8704):
    y = Mean_1800nm_800nm[i]*0.22
    Force_1800nm_800nm.append(y)

# %%
#Shifting
Shifted_forces = []
for forces in [Force_1800nm_1um, Force_1800nm_3um, Force_1800nm_5um, Force_1800nm_7um, Force_1800nm_10um, Force_1800nm_15um, Force_1800nm_20um, Force_1800nm_500nm, Force_1800nm_800nm]:
    forces = np.array(forces)
    min = forces.min()
    Shifted_Force = []
    for i in range(len(forces)):
        X = float(forces[i]) - min
        Shifted_Force.append(X)
    Shifted_forces.append(Shifted_Force)

# %%
#Distance of the plate and sphere

w = 1.568*10**-9          #roughness in m (200nm)
d_plate = 26.75*10**-9    #in m
d_sphere = 2.2*10**-8  #in m

if d_sphere > 10**6*d_plate:
    d_00 = d_sphere + w

else: d_00 = d_sphere + d_plate
print(d_00)
d_0 = d_00*10**9

d_0_2 = (d_sphere + w)*10**9
print(d_0_2)
print(d_0)      #d_0 is the final distance.
# Out:
# 4.875e-08
# 23.568
# 48.75

# %% [markdown]
# ### List of distances
# 1 --> 600
# 3 --> 600
# 5 --> 600
# 7 --> 600
# 10 --> 600
# 15 --> 600
# 20 --> 2000
# 0.5 --> 600
# 0.8 --> 2000

# %% [markdown]
# ### 1um

# %%
# Define the known points
x = [float(separation[8450]), float(separation[8700])]
y = [float(Shifted_forces[0][8450]), float(Shifted_forces[0][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[0])
plt.xlim(600,1010)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[0])
plt.xlim(957,970)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.1962825811461776
# b = -188.9413864539858

# %%
x1 = 9.645*10**2                 #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_1um = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_1um.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_1um)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 964.5
# variation_d is 35.35169999999994
# d_0 is 48.75
# ...

# %% [markdown]
# ### 3um

# %%
# Define the known points
x = [float(separation[8450]), float(separation[8600])]
y = [float(Shifted_forces[1][8450]), float(Shifted_forces[1][8600])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[1])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[1])
plt.xlim(960,975)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.19053204343236346
# b = -183.33941746614846

# %%
x1 = 9.68*10**2                 #from graph in nm
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_3um = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_3um.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_3um)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 968.0
# variation_d is 31.851699999999937
# d_0 is 48.75
# ...

# %% [markdown]
# ### 5um

# %%
# Define the known points
x = [float(separation[8550]), float(separation[8700])]
y = [float(Shifted_forces[2][8550]), float(Shifted_forces[2][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[2])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[2])
plt.xlim(970,985)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.19309563182255884
# b = -185.79095028400712

# %%
x1 = 9.77*10**2                 #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_5um = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_5um.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_5um)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 977.0
# variation_d is 22.851699999999937
# d_0 is 48.75
# ...

# %% [markdown]
# ### 7um

# %%
# Define the known points
x = [float(separation[8500]), float(separation[8700])]
y = [float(Shifted_forces[3][8500]), float(Shifted_forces[3][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[3])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[3])
plt.xlim(950,970)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.1918645852365498
# b = -184.49680485956955

# %%
x1 =                   #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_7um = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_7um.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_7um)
# Out:
#   Cell In[15], line 1
#     x1 =                   #from graph in nm up above
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 10um

# %%
# Define the known points
x = [float(separation[8500]), float(separation[8700])]
y = [float(Shifted_forces[4][8500]), float(Shifted_forces[4][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[4])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[4])
plt.xlim(960,975)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.19230249440998104
# b = -184.94582174198743

# %%
x1 = 9.73*10**2                 #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_10um = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_10um.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_10um)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 973.0
# variation_d is 26.851699999999937
# d_0 is 48.75
# ...

# %% [markdown]
# ### 15um

# %%
# Define the known points
x = [float(separation[8590]), float(separation[8700])]
y = [float(Shifted_forces[5][8590]), float(Shifted_forces[5][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[5])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[5])
plt.xlim(960,973)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.1791992754941419
# b = -171.84717565339568

# %%
x1 = 9.66*10**2                 #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_15um = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_15um.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_15um)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 966.0
# variation_d is 33.85169999999994
# d_0 is 48.75
# ...

# %% [markdown]
# ### 20um

# %%
# Define the known points
x = [float(separation[8500]), float(separation[8700])]
y = [float(Shifted_forces[6][8500]), float(Shifted_forces[6][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[6])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[6])
plt.xlim(960,975)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.19114609090197238
# b = -183.80776193204852

# %%
x1 = 9.71*10**2                 #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_20um = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_20um.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_20um)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 971.0000000000001
# variation_d is 28.851699999999823
# d_0 is 48.75
# ...

# %% [markdown]
# ### 500nm

# %%
# Define the known points
x = [float(separation[8450]), float(separation[8700])]
y = [float(Shifted_forces[7][8450]), float(Shifted_forces[7][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[7])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[7])
plt.xlim(965,967)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.1929700198021194
# b = -185.65768590175492

# %%
x1 = 9.66*10**2                 #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_500nm = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_500nm.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_500nm)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 966.0
# variation_d is 33.85169999999994
# d_0 is 48.75
# ...

# %% [markdown]
# ### 800nm

# %%
# Define the known points
x = [float(separation[8500]), float(separation[8700])]
y = [float(Shifted_forces[8][8500]), float(Shifted_forces[8][8700])]

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(float(separation[8000]), float(separation[8700]),100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[8])
plt.xlim(600,1010)
plt.ylim(-1,9)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(separation)):
    sep.append(float(separation[i]))
plt.plot(sep, Shifted_forces[8])
plt.xlim(955,970)
plt.ylim(-1,7)
plt.show()
# Out:
# a = 0.2045721335539096
# b = -197.2717881691398

# %%
x1 = 9.67*10**2                 #from graph in nm up above
variation_d = 9.998517*10**2 - x1     #from graph in nm

d_final_1800nm_800nm = []

for i in range(len(separation)):
    X = (float(separation[i]) - x1 + d_0 - variation_d)*-1 +d_0
    d_final_1800nm_800nm.append(X)

print(f"separation at 8700 is {float(separation[8700])}")
print((float(separation[8700]) - x1 + d_0 - variation_d)*-1)
print(f"x1 is {x1}")
print(f"variation_d is {variation_d}")
print(f"d_0 is {d_0}")
print(d_final_1800nm_800nm)
# Out:
# separation at 8700 is 999.5069
# -48.405200000000036
# x1 is 967.0
# variation_d is 32.85169999999994
# d_0 is 48.75
# ...

# %% [markdown]
# ### Save all files

# %%
np.savetxt('Shifted_Force_1800nm_1um.csv', Shifted_forces[0], delimiter=',')
np.savetxt('Shifted_Force_1800nm_3um.csv', Shifted_forces[1], delimiter=',')
np.savetxt('Shifted_Force_1800nm_5um.csv', Shifted_forces[2], delimiter=',')
np.savetxt('Shifted_Force_1800nm_7um.csv', Shifted_forces[3], delimiter=',')
np.savetxt('Shifted_Force_1800nm_10um.csv', Shifted_forces[4], delimiter=',')
np.savetxt('Shifted_Force_1800nm_15um.csv', Shifted_forces[5], delimiter=',')
np.savetxt('Shifted_Force_1800nm_20um.csv', Shifted_forces[6], delimiter=',')
np.savetxt('Shifted_Force_1800nm_500nm.csv', Shifted_forces[7], delimiter=',')
np.savetxt('Shifted_Force_1800nm_800nm.csv', Shifted_forces[8], delimiter=',')


np.savetxt('d_final_1800nm_1um.csv', d_final_1800nm_1um, delimiter=',')
np.savetxt('d_final_1800nm_3um.csv', d_final_1800nm_3um, delimiter=',')
np.savetxt('d_final_1800nm_5um.csv', d_final_1800nm_5um, delimiter=',')
#np.savetxt('d_final_1800nm_7um.csv', d_final_1800nm_7um, delimiter=',')
np.savetxt('d_final_1800nm_10um.csv', d_final_1800nm_10um, delimiter=',')
np.savetxt('d_final_1800nm_15um.csv', d_final_1800nm_15um, delimiter=',')
np.savetxt('d_final_1800nm_20um.csv', d_final_1800nm_20um, delimiter=',')
np.savetxt('d_final_1800nm_500nm.csv', d_final_1800nm_500nm, delimiter=',')
np.savetxt('d_final_1800nm_800nm.csv', d_final_1800nm_800nm, delimiter=',')

# %% [markdown]
# ### Waiting for confirmation

# %%
np.savetxt('d_final_1800nm_7um.csv', d_final_1800nm_7um, delimiter=',')
