# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
import statistics as stat

# %%
#Au_Au
Au_Au_Shifted_Force_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_1um.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_1um = Au_Au_Shifted_Force_1800nm_1um.values.tolist()
Au_Au_Shifted_Force_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_3um.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_3um = Au_Au_Shifted_Force_1800nm_3um.values.tolist()
Au_Au_Shifted_Force_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_5um.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_5um = Au_Au_Shifted_Force_1800nm_5um.values.tolist()
Au_Au_Shifted_Force_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_7um.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_7um = Au_Au_Shifted_Force_1800nm_7um.values.tolist()
Au_Au_Shifted_Force_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_10um.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_10um = Au_Au_Shifted_Force_1800nm_10um.values.tolist()
Au_Au_Shifted_Force_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_15um.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_15um = Au_Au_Shifted_Force_1800nm_15um.values.tolist()
Au_Au_Shifted_Force_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_20um.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_20um = Au_Au_Shifted_Force_1800nm_20um.values.tolist()
Au_Au_Shifted_Force_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_500nm.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_500nm = Au_Au_Shifted_Force_1800nm_500nm.values.tolist()
Au_Au_Shifted_Force_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final forces\Shifted_Force_1800nm_800nm.csv', names=['Force'])
Au_Au_Shifted_Force_1800nm_800nm = Au_Au_Shifted_Force_1800nm_800nm.values.tolist()

Au_Au_d_final_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_1um.csv', names=['Force'])
Au_Au_d_final_1800nm_1um = Au_Au_d_final_1800nm_1um.values.tolist()
Au_Au_d_final_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_3um.csv', names=['Force'])
Au_Au_d_final_1800nm_3um = Au_Au_d_final_1800nm_3um.values.tolist()
Au_Au_d_final_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_5um.csv', names=['Force'])
Au_Au_d_final_1800nm_5um = Au_Au_d_final_1800nm_5um.values.tolist()
Au_Au_d_final_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_7um.csv', names=['Force'])
Au_Au_d_final_1800nm_7um = Au_Au_d_final_1800nm_7um.values.tolist()
Au_Au_d_final_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_10um.csv', names=['Force'])
Au_Au_d_final_1800nm_10um = Au_Au_d_final_1800nm_10um.values.tolist()
Au_Au_d_final_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_15um.csv', names=['Force'])
Au_Au_d_final_1800nm_15um = Au_Au_d_final_1800nm_15um.values.tolist()
Au_Au_d_final_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_20um.csv', names=['Force'])
Au_Au_d_final_1800nm_20um = Au_Au_d_final_1800nm_20um.values.tolist()
Au_Au_d_final_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_500nm.csv', names=['Force'])
Au_Au_d_final_1800nm_500nm = Au_Au_d_final_1800nm_500nm.values.tolist()
Au_Au_d_final_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_Au\Exported data\Final distances\d_final_1800nm_800nm.csv', names=['Force'])
Au_Au_d_final_1800nm_800nm = Au_Au_d_final_1800nm_800nm.values.tolist()


#Si_BSG
Si_BSG_Shifted_Force_100nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_1um.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_1um = Si_BSG_Shifted_Force_100nm_1um.values.tolist()
Si_BSG_Shifted_Force_100nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_5um.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_5um = Si_BSG_Shifted_Force_100nm_5um.values.tolist()
Si_BSG_Shifted_Force_100nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_7um.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_7um = Si_BSG_Shifted_Force_100nm_7um.values.tolist()
Si_BSG_Shifted_Force_100nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_10um.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_10um = Si_BSG_Shifted_Force_100nm_10um.values.tolist()
Si_BSG_Shifted_Force_100nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_15um.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_15um = Si_BSG_Shifted_Force_100nm_15um.values.tolist()
Si_BSG_Shifted_Force_100nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_20um.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_20um = Si_BSG_Shifted_Force_100nm_20um.values.tolist()
Si_BSG_Shifted_Force_100nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_500nm.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_500nm = Si_BSG_Shifted_Force_100nm_500nm.values.tolist()
Si_BSG_Shifted_Force_100nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final forces\Shifted_Force_100nm_800nm.csv', names=['Force'])
Si_BSG_Shifted_Force_100nm_800nm = Si_BSG_Shifted_Force_100nm_800nm.values.tolist()

Si_BSG_d_final_100nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_1um.csv', names=['Force'])
Si_BSG_d_final_100nm_1um = Si_BSG_d_final_100nm_1um.values.tolist()
Si_BSG_d_final_100nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_5um.csv', names=['Force'])
Si_BSG_d_final_100nm_5um = Si_BSG_d_final_100nm_5um.values.tolist()
Si_BSG_d_final_100nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_7um.csv', names=['Force'])
Si_BSG_d_final_100nm_7um = Si_BSG_d_final_100nm_7um.values.tolist()
Si_BSG_d_final_100nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_10um.csv', names=['Force'])
Si_BSG_d_final_100nm_10um = Si_BSG_d_final_100nm_10um.values.tolist()
Si_BSG_d_final_100nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_15um.csv', names=['Force'])
Si_BSG_d_final_100nm_15um = Si_BSG_d_final_100nm_15um.values.tolist()
Si_BSG_d_final_100nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_20um.csv', names=['Force'])
Si_BSG_d_final_100nm_20um = Si_BSG_d_final_100nm_20um.values.tolist()
Si_BSG_d_final_100nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_500nm.csv', names=['Force'])
Si_BSG_d_final_100nm_500nm = Si_BSG_d_final_100nm_500nm.values.tolist()
Si_BSG_d_final_100nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Si_BSG\Exported data\Final distances\d_final_100nm_800nm.csv', names=['Force'])
Si_BSG_d_final_100nm_800nm = Si_BSG_d_final_100nm_800nm.values.tolist()


#Au_BSG_X1
Au_BSG_X1_Shifted_Force_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_1um.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_1um = Au_BSG_X1_Shifted_Force_1800nm_1um.values.tolist()
Au_BSG_X1_Shifted_Force_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_3um.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_3um = Au_BSG_X1_Shifted_Force_1800nm_3um.values.tolist()
#Au_BSG_X1_Shifted_Force_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_5um.csv', names=['Force'])
#Au_BSG_X1_Shifted_Force_1800nm_5um = Au_BSG_X1_Shifted_Force_1800nm_5um.values.tolist()
Au_BSG_X1_Shifted_Force_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_7um.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_7um = Au_BSG_X1_Shifted_Force_1800nm_7um.values.tolist()
Au_BSG_X1_Shifted_Force_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_10um.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_10um = Au_BSG_X1_Shifted_Force_1800nm_10um.values.tolist()
Au_BSG_X1_Shifted_Force_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_15um.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_15um = Au_BSG_X1_Shifted_Force_1800nm_15um.values.tolist()
Au_BSG_X1_Shifted_Force_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_20um.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_20um = Au_BSG_X1_Shifted_Force_1800nm_20um.values.tolist()
Au_BSG_X1_Shifted_Force_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_500nm.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_500nm = Au_BSG_X1_Shifted_Force_1800nm_500nm.values.tolist()
Au_BSG_X1_Shifted_Force_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final forces\Shifted_Force_1800nm_800nm.csv', names=['Force'])
Au_BSG_X1_Shifted_Force_1800nm_800nm = Au_BSG_X1_Shifted_Force_1800nm_800nm.values.tolist()

Au_BSG_X1_d_final_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_1um.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_1um = Au_BSG_X1_d_final_1800nm_1um.values.tolist()
Au_BSG_X1_d_final_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_3um.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_3um = Au_BSG_X1_d_final_1800nm_3um.values.tolist()
#Au_BSG_X1_d_final_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_5um.csv', names=['Force'])
#Au_BSG_X1_d_final_1800nm_5um = Au_BSG_X1_d_final_1800nm_5um.values.tolist()
Au_BSG_X1_d_final_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_7um.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_7um = Au_BSG_X1_d_final_1800nm_7um.values.tolist()
Au_BSG_X1_d_final_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_10um.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_10um = Au_BSG_X1_d_final_1800nm_10um.values.tolist()
Au_BSG_X1_d_final_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_15um.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_15um = Au_BSG_X1_d_final_1800nm_15um.values.tolist()
Au_BSG_X1_d_final_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_20um.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_20um = Au_BSG_X1_d_final_1800nm_20um.values.tolist()
Au_BSG_X1_d_final_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_500nm.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_500nm = Au_BSG_X1_d_final_1800nm_500nm.values.tolist()
Au_BSG_X1_d_final_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X1\Exported data\Final distances\d_final_1800nm_800nm.csv', names=['Force'])
Au_BSG_X1_d_final_1800nm_800nm = Au_BSG_X1_d_final_1800nm_800nm.values.tolist()


#Au_BSG_X2
Au_BSG_X2_Shifted_Force_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_1um.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_1um = Au_BSG_X2_Shifted_Force_1800nm_1um.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_3um.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_3um = Au_BSG_X2_Shifted_Force_1800nm_3um.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_5um.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_5um = Au_BSG_X2_Shifted_Force_1800nm_5um.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_7um.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_7um = Au_BSG_X2_Shifted_Force_1800nm_7um.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_10um.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_10um = Au_BSG_X2_Shifted_Force_1800nm_10um.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_15um.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_15um = Au_BSG_X2_Shifted_Force_1800nm_15um.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_20um.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_20um = Au_BSG_X2_Shifted_Force_1800nm_20um.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_500nm.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_500nm = Au_BSG_X2_Shifted_Force_1800nm_500nm.values.tolist()
Au_BSG_X2_Shifted_Force_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final forces\Shifted_Force_1800nm_800nm.csv', names=['Force'])
Au_BSG_X2_Shifted_Force_1800nm_800nm = Au_BSG_X2_Shifted_Force_1800nm_800nm.values.tolist()

Au_BSG_X2_d_final_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_1um.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_1um = Au_BSG_X2_d_final_1800nm_1um.values.tolist()
Au_BSG_X2_d_final_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_3um.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_3um = Au_BSG_X2_d_final_1800nm_3um.values.tolist()
Au_BSG_X2_d_final_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_5um.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_5um = Au_BSG_X2_d_final_1800nm_5um.values.tolist()
Au_BSG_X2_d_final_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_7um.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_7um = Au_BSG_X2_d_final_1800nm_7um.values.tolist()
Au_BSG_X2_d_final_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_10um.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_10um = Au_BSG_X2_d_final_1800nm_10um.values.tolist()
Au_BSG_X2_d_final_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_15um.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_15um = Au_BSG_X2_d_final_1800nm_15um.values.tolist()
Au_BSG_X2_d_final_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_20um.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_20um = Au_BSG_X2_d_final_1800nm_20um.values.tolist()
Au_BSG_X2_d_final_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_500nm.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_500nm = Au_BSG_X2_d_final_1800nm_500nm.values.tolist()
Au_BSG_X2_d_final_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X2\Exported data\Final distances\d_final_1800nm_800nm.csv', names=['Force'])
Au_BSG_X2_d_final_1800nm_800nm = Au_BSG_X2_d_final_1800nm_800nm.values.tolist()


#Au_BSG_X3
Au_BSG_X3_Shifted_Force_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_1um.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_1um = Au_BSG_X3_Shifted_Force_1800nm_1um.values.tolist()
Au_BSG_X3_Shifted_Force_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_3um.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_3um = Au_BSG_X3_Shifted_Force_1800nm_3um.values.tolist()
Au_BSG_X3_Shifted_Force_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_5um.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_5um = Au_BSG_X3_Shifted_Force_1800nm_5um.values.tolist()
#Au_BSG_X3_Shifted_Force_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_7um.csv', names=['Force'])
#Au_BSG_X3_Shifted_Force_1800nm_7um = Au_BSG_X3_Shifted_Force_1800nm_7um.values.tolist()
Au_BSG_X3_Shifted_Force_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_10um.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_10um = Au_BSG_X3_Shifted_Force_1800nm_10um.values.tolist()
Au_BSG_X3_Shifted_Force_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_15um.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_15um = Au_BSG_X3_Shifted_Force_1800nm_15um.values.tolist()
Au_BSG_X3_Shifted_Force_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_20um.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_20um = Au_BSG_X3_Shifted_Force_1800nm_20um.values.tolist()
Au_BSG_X3_Shifted_Force_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_500nm.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_500nm = Au_BSG_X3_Shifted_Force_1800nm_500nm.values.tolist()
Au_BSG_X3_Shifted_Force_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final forces\Shifted_Force_1800nm_800nm.csv', names=['Force'])
Au_BSG_X3_Shifted_Force_1800nm_800nm = Au_BSG_X3_Shifted_Force_1800nm_800nm.values.tolist()

Au_BSG_X3_d_final_1800nm_1um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_1um.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_1um = Au_BSG_X3_d_final_1800nm_1um.values.tolist()
Au_BSG_X3_d_final_1800nm_3um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_3um.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_3um = Au_BSG_X3_d_final_1800nm_3um.values.tolist()
Au_BSG_X3_d_final_1800nm_5um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_5um.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_5um = Au_BSG_X3_d_final_1800nm_5um.values.tolist()
#Au_BSG_X3_d_final_1800nm_7um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_7um.csv', names=['Force'])
#Au_BSG_X3_d_final_1800nm_7um = Au_BSG_X3_d_final_1800nm_7um.values.tolist()
Au_BSG_X3_d_final_1800nm_10um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_10um.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_10um = Au_BSG_X3_d_final_1800nm_10um.values.tolist()
Au_BSG_X3_d_final_1800nm_15um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_15um.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_15um = Au_BSG_X3_d_final_1800nm_15um.values.tolist()
Au_BSG_X3_d_final_1800nm_20um = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_20um.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_20um = Au_BSG_X3_d_final_1800nm_20um.values.tolist()
Au_BSG_X3_d_final_1800nm_500nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_500nm.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_500nm = Au_BSG_X3_d_final_1800nm_500nm.values.tolist()
Au_BSG_X3_d_final_1800nm_800nm = pd.read_csv(r'\Users\Mikel\Documents\00 - Universidades\2 - RUG_Physics\HC project\Code\Hydrodynamic_force_low_velocities\Data_Au_BSG\X3\Exported data\Final distances\d_final_1800nm_800nm.csv', names=['Force'])
Au_BSG_X3_d_final_1800nm_800nm = Au_BSG_X3_d_final_1800nm_800nm.values.tolist()

# %% [markdown]
# ### Classical formula

# %%
def Hydro_forces(v,d,r,n):
    return (v*6*math.pi*r**2*n)*10**12/(d*10**-9)

# %% [markdown]
# # Final report graphs

# %%
r = 10**-6 #radius of sphere in m
n = 0.0011439 #viscosity in Pa/s, for 20 degrees celcius
d = np.linspace(0,2000,20000)
xlim = (0,140)
ylim = (-0.4,7)


plt.plot(Au_Au_d_final_1800nm_1um, Au_Au_Shifted_Force_1800nm_1um, color='royalblue', label='Au vs Au')
plt.plot(Si_BSG_d_final_100nm_1um, Si_BSG_Shifted_Force_100nm_1um, color='red', label='Si vs BSG')
plt.plot(Au_BSG_d_final_1800nm_1um, Au_BSG_Shifted_Force_1800nm_1um, color='darkorange', label='Au vs BSG')
plt.title(r'$1 \mu m/s$',fontsize='17')
plt.xlabel('Separation distance (nm)', fontsize='14')
plt.ylabel('Hydrodynamic Force (nN)', fontsize='14')
plt.legend(fontsize='12')
plt.grid()
plt.xlim(xlim)
plt.ylim(ylim)

plt.show()

figure, ax = plt.subplots(3, 3,figsize=(15, 15)) 

ax[0,0].plot(Au_Au_d_final_1800nm_500nm, Au_Au_Shifted_Force_1800nm_500nm, color='royalblue', label='Au vs Au')
ax[0,0].plot(Si_BSG_d_final_100nm_500nm, Si_BSG_Shifted_Force_100nm_500nm, color='red', label='Si vs BSG')
ax[0,0].plot(Au_BSG_d_final_1800nm_500nm, Au_BSG_Shifted_Force_1800nm_500nm, color='darkorange', label='Au vs BSG')
ax[0,0].set_title(r'$0.5 \mu m/s$',fontsize='17')
ax[0,0].legend(fontsize='12')
ax[0,0].grid()
ax[0,0].set_xlim(xlim)
ax[0,0].set_ylim(ylim)

ax[0,1].plot(Au_Au_d_final_1800nm_800nm, Au_Au_Shifted_Force_1800nm_800nm, color='royalblue', label='Au vs Au')
ax[0,1].plot(Si_BSG_d_final_100nm_800nm, Si_BSG_Shifted_Force_100nm_800nm, color='red', label='Si vs BSG')
ax[0,1].plot(Au_BSG_d_final_1800nm_800nm, Au_BSG_Shifted_Force_1800nm_800nm, color='darkorange', label='Au vs BSG')
ax[0,1].set_title(r'$0.8 \mu m/s$',fontsize='17')
ax[0,1].legend(fontsize='12')
ax[0,1].grid()
ax[0,1].set_xlim(xlim)
ax[0,1].set_ylim(ylim)

ax[0,2].plot(Au_Au_d_final_1800nm_1um, Au_Au_Shifted_Force_1800nm_1um, color='royalblue', label='Au vs Au')
ax[0,2].plot(Si_BSG_d_final_100nm_1um, Si_BSG_Shifted_Force_100nm_1um, color='red', label='Si vs BSG')
ax[0,2].plot(Au_BSG_d_final_1800nm_1um, Au_BSG_Shifted_Force_1800nm_1um, color='darkorange', label='Au vs BSG')
ax[0,2].set_title(r'$1 \mu m/s$',fontsize='17')
ax[0,2].legend(fontsize='12')
ax[0,2].grid()
ax[0,2].set_xlim(xlim)
ax[0,2].set_ylim(ylim)

ax[1,0].plot(Au_Au_d_final_1800nm_3um, Au_Au_Shifted_Force_1800nm_3um, color='royalblue', label='Au vs Au')
ax[1,0].plot(Au_BSG_d_final_1800nm_3um, Au_BSG_Shifted_Force_1800nm_3um, color='darkorange', label='Au vs BSG')
ax[1,0].set_title(r'$3 \mu m/s$',fontsize='17')
ax[1,0].legend(fontsize='12')
ax[1,0].grid()
ax[1,0].set_xlim(xlim)
ax[1,0].set_ylim(ylim)

ax[1,1].plot(Au_Au_d_final_1800nm_5um, Au_Au_Shifted_Force_1800nm_5um, color='royalblue', label='Au vs Au')
ax[1,1].plot(Si_BSG_d_final_100nm_5um, Si_BSG_Shifted_Force_100nm_5um, color='red', label='Si vs BSG')
ax[1,1].set_title(r'$5 \mu m/s$',fontsize='17')
ax[1,1].legend(fontsize='12')
ax[1,1].grid()
ax[1,1].set_xlim(xlim)
ax[1,1].set_ylim(ylim)

ax[1,2].plot(Au_Au_d_final_1800nm_7um, Au_Au_Shifted_Force_1800nm_7um, color='royalblue', label='Au vs Au')
ax[1,2].plot(Si_BSG_d_final_100nm_7um, Si_BSG_Shifted_Force_100nm_7um, color='red', label='Si vs BSG')
ax[1,2].set_title(r'$7 \mu m/s$',fontsize='17')
ax[1,2].legend(fontsize='12')
ax[1,2].grid()
ax[1,2].set_xlim(xlim)
ax[1,2].set_ylim(ylim)

ax[2,0].plot(Au_Au_d_final_1800nm_10um, Au_Au_Shifted_Force_1800nm_10um, color='royalblue', label='Au vs Au')
ax[2,0].plot(Si_BSG_d_final_100nm_10um, Si_BSG_Shifted_Force_100nm_10um, color='red', label='Si vs BSG')
ax[2,0].plot(Au_BSG_d_final_1800nm_10um, Au_BSG_Shifted_Force_1800nm_10um, color='darkorange', label='Au vs BSG')
ax[2,0].set_title(r'$10 \mu m/s$',fontsize='17')
ax[2,0].legend(fontsize='12')
ax[2,0].grid()
ax[2,0].set_xlim(xlim)
ax[2,0].set_ylim(ylim)

ax[2,1].plot(Au_Au_d_final_1800nm_15um, Au_Au_Shifted_Force_1800nm_15um, color='royalblue', label='Au vs Au')
ax[2,1].plot(Si_BSG_d_final_100nm_15um, Si_BSG_Shifted_Force_100nm_15um, color='red', label='Si vs BSG')
ax[2,1].plot(Au_BSG_d_final_1800nm_15um, Au_BSG_Shifted_Force_1800nm_15um, color='darkorange', label='Au vs BSG')
ax[2,1].set_title(r'$15 \mu m/s$',fontsize='17')
ax[2,1].legend(fontsize='12')
ax[2,1].grid()
ax[2,1].set_xlim(xlim)
ax[2,1].set_ylim(ylim)

ax[2,2].plot(Au_Au_d_final_1800nm_20um, Au_Au_Shifted_Force_1800nm_20um, color='royalblue', label='Au vs Au')
ax[2,2].plot(Si_BSG_d_final_100nm_20um, Si_BSG_Shifted_Force_100nm_20um, color='red', label='Si vs BSG')
ax[2,2].plot(Au_BSG_d_final_1800nm_20um, Au_BSG_Shifted_Force_1800nm_20um, color='darkorange', label='Au vs BSG')
ax[2,2].set_title(r'$20 \mu m/s$',fontsize='17')
ax[2,2].legend(fontsize='12')
ax[2,2].grid()
ax[2,2].set_xlim(xlim)
ax[2,2].set_ylim(ylim)
plt.show()

# %% [markdown]
# ### Plot: experimental results for different setups

# %%
r = 10**-6 #radius of sphere in m
n = 0.0011439 #viscosity in Pa/s, for 20 degrees celcius
d = np.linspace(0,2000,20000)
xlim = (0,200)
ylim = (-0.5,4)

figure, ax = plt.subplots(3, 3,figsize=(15, 15)) 

ax[0,0].plot(Au_Au_d_final_1800nm_1um, Au_Au_Shifted_Force_1800nm_1um, label='Au vs Au')
ax[0,0].plot(Si_BSG_d_final_100nm_1um, Si_BSG_Shifted_Force_100nm_1um, label='Si vs BSG')
ax[0,0].plot(Au_BSG_X1_d_final_1800nm_1um, Au_BSG_X1_Shifted_Force_1800nm_1um, label='Au vs BSG (X1)')
ax[0,0].plot(Au_BSG_X2_d_final_1800nm_1um, Au_BSG_X2_Shifted_Force_1800nm_1um, label='Au vs BSG (X2)')
ax[0,0].plot(Au_BSG_X3_d_final_1800nm_1um, Au_BSG_X3_Shifted_Force_1800nm_1um, label='Au vs BSG (X3)')
ax[0,0].set_title("1um/s")
ax[0,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,0].legend()
ax[0,0].grid()
ax[0,0].set_xlim(xlim)
ax[0,0].set_ylim(ylim)

ax[0,1].plot(Au_Au_d_final_1800nm_3um, Au_Au_Shifted_Force_1800nm_3um, label='Au vs Au')
#ax[0,1].plot(Si_BSG_d_final_100nm_3um, Si_BSG_Shifted_Force_100nm_3um, label='Si vs BSG')
ax[0,1].plot(Au_BSG_X1_d_final_1800nm_3um, Au_BSG_X1_Shifted_Force_1800nm_3um, label='Au vs BSG (X1)')
ax[0,1].plot(Au_BSG_X2_d_final_1800nm_3um, Au_BSG_X2_Shifted_Force_1800nm_3um, label='Au vs BSG (X2)')
ax[0,1].plot(Au_BSG_X3_d_final_1800nm_3um, Au_BSG_X3_Shifted_Force_1800nm_3um, label='Au vs BSG (X3)')
ax[0,1].set_title("3um/s")
ax[0,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,1].legend()
ax[0,1].grid()
ax[0,1].set_xlim(xlim)
ax[0,1].set_ylim(ylim)

ax[0,2].plot(Au_Au_d_final_1800nm_5um, Au_Au_Shifted_Force_1800nm_5um, label='Au vs Au')
ax[0,2].plot(Si_BSG_d_final_100nm_5um, Si_BSG_Shifted_Force_100nm_5um, label='Si vs BSG')
#ax[0,2].plot(Au_BSG_X1_d_final_1800nm_5um, Au_BSG_X1_Shifted_Force_1800nm_5um, label='Au vs BSG (X1)')
ax[0,2].plot(Au_BSG_X2_d_final_1800nm_5um, Au_BSG_X2_Shifted_Force_1800nm_5um, label='Au vs BSG (X2)')
ax[0,2].plot(Au_BSG_X3_d_final_1800nm_5um, Au_BSG_X3_Shifted_Force_1800nm_5um, label='Au vs BSG (X3)')
ax[0,2].set_title("5um/s")
ax[0,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,2].legend()
ax[0,2].grid()
ax[0,2].set_xlim(xlim)
ax[0,2].set_ylim(ylim)

ax[1,0].plot(Au_Au_d_final_1800nm_7um, Au_Au_Shifted_Force_1800nm_7um, label='Au vs Au')
ax[1,0].plot(Si_BSG_d_final_100nm_7um, Si_BSG_Shifted_Force_100nm_7um, label='Si vs BSG')
ax[1,0].plot(Au_BSG_X1_d_final_1800nm_7um, Au_BSG_X1_Shifted_Force_1800nm_7um, label='Au vs BSG (X1)')
ax[1,0].plot(Au_BSG_X2_d_final_1800nm_7um, Au_BSG_X2_Shifted_Force_1800nm_7um, label='Au vs BSG (X2)')
#ax[1,0].plot(Au_BSG_X3_d_final_1800nm_7um, Au_BSG_X3_Shifted_Force_1800nm_7um, label='Au vs BSG (X3)')
ax[1,0].set_title("7um/s")
ax[1,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,0].legend()
ax[1,0].grid()
ax[1,0].set_xlim(xlim)
ax[1,0].set_ylim(ylim)

ax[1,1].plot(Au_Au_d_final_1800nm_10um, Au_Au_Shifted_Force_1800nm_10um, label='Au vs Au')
ax[1,1].plot(Si_BSG_d_final_100nm_10um, Si_BSG_Shifted_Force_100nm_10um, label='Si vs BSG')
ax[1,1].plot(Au_BSG_X1_d_final_1800nm_10um, Au_BSG_X1_Shifted_Force_1800nm_10um, label='Au vs BSG (X1)')
ax[1,1].plot(Au_BSG_X2_d_final_1800nm_10um, Au_BSG_X2_Shifted_Force_1800nm_10um, label='Au vs BSG (X2)')
ax[1,1].plot(Au_BSG_X3_d_final_1800nm_10um, Au_BSG_X3_Shifted_Force_1800nm_10um, label='Au vs BSG (X3)')
ax[1,1].set_title("10um/s")
ax[1,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,1].legend()
ax[1,1].grid()
ax[1,1].set_xlim(xlim)
ax[1,1].set_ylim(ylim)

ax[1,2].plot(Au_Au_d_final_1800nm_15um, Au_Au_Shifted_Force_1800nm_15um, label='Au vs Au')
ax[1,2].plot(Si_BSG_d_final_100nm_15um, Si_BSG_Shifted_Force_100nm_15um, label='Si vs BSG')
ax[1,2].plot(Au_BSG_X1_d_final_1800nm_15um, Au_BSG_X1_Shifted_Force_1800nm_15um, label='Au vs BSG (X1)')
ax[1,2].plot(Au_BSG_X2_d_final_1800nm_15um, Au_BSG_X2_Shifted_Force_1800nm_15um, label='Au vs BSG (X2)')
ax[1,2].plot(Au_BSG_X3_d_final_1800nm_15um, Au_BSG_X3_Shifted_Force_1800nm_15um, label='Au vs BSG (X3)')
ax[1,2].set_title("15um/s")
ax[1,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,2].legend()
ax[1,2].grid()
ax[1,2].set_xlim(xlim)
ax[1,2].set_ylim(ylim)

ax[2,0].plot(Au_Au_d_final_1800nm_20um, Au_Au_Shifted_Force_1800nm_20um, label='Si vs BSG')
ax[2,0].plot(Si_BSG_d_final_100nm_20um, Si_BSG_Shifted_Force_100nm_20um, label='Si vs BSG')
ax[2,0].plot(Au_BSG_X1_d_final_1800nm_20um, Au_BSG_X1_Shifted_Force_1800nm_20um, label='Au vs BSG (X1)')
ax[2,0].plot(Au_BSG_X2_d_final_1800nm_20um, Au_BSG_X2_Shifted_Force_1800nm_20um, label='Au vs BSG (X2)')
ax[2,0].plot(Au_BSG_X3_d_final_1800nm_20um, Au_BSG_X3_Shifted_Force_1800nm_20um, label='Au vs BSG (X3)')
ax[2,0].set_title("20um/s")
ax[2,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,0].legend()
ax[2,0].grid()
ax[2,0].set_xlim(xlim)
ax[2,0].set_ylim(ylim)

ax[2,1].plot(Au_Au_d_final_1800nm_500nm, Au_Au_Shifted_Force_1800nm_500nm, label='Si vs BSG')
ax[2,1].plot(Si_BSG_d_final_100nm_500nm, Si_BSG_Shifted_Force_100nm_500nm, label='Si vs BSG')
ax[2,1].plot(Au_BSG_X1_d_final_1800nm_500nm, Au_BSG_X1_Shifted_Force_1800nm_500nm, label='Au vs BSG (X1)')
ax[2,1].plot(Au_BSG_X2_d_final_1800nm_500nm, Au_BSG_X2_Shifted_Force_1800nm_500nm, label='Au vs BSG (X2)')
ax[2,1].plot(Au_BSG_X3_d_final_1800nm_500nm, Au_BSG_X3_Shifted_Force_1800nm_500nm, label='Au vs BSG (X3)')
ax[2,1].set_title("500nm/s")
ax[2,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,1].legend()
ax[2,1].grid()
ax[2,1].set_xlim(xlim)
ax[2,1].set_ylim(ylim)

ax[2,2].plot(Au_Au_d_final_1800nm_800nm, Au_Au_Shifted_Force_1800nm_800nm, label='Si vs BSG')
ax[2,2].plot(Si_BSG_d_final_100nm_800nm, Si_BSG_Shifted_Force_100nm_800nm, label='Si vs BSG')
ax[2,2].plot(Au_BSG_X1_d_final_1800nm_800nm, Au_BSG_X1_Shifted_Force_1800nm_800nm, label='Au vs BSG (X1)')
ax[2,2].plot(Au_BSG_X2_d_final_1800nm_800nm, Au_BSG_X2_Shifted_Force_1800nm_800nm, label='Au vs BSG (X2)')
ax[2,2].plot(Au_BSG_X3_d_final_1800nm_800nm, Au_BSG_X3_Shifted_Force_1800nm_800nm, label='Au vs BSG (X3)')
ax[2,2].set_title("500nm/s")
ax[2,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,2].legend()
ax[2,2].grid()
ax[2,2].set_xlim(xlim)
ax[2,2].set_ylim(ylim)

plt.show()

# %% [markdown]
# ### Plot: experimental results for different setups with classical formula

# %%
r = 10**-6 #radius of sphere
n = 0.0011439 #viscosity in Pa/s, for 20 degrees celcius
d = np.linspace(0,2000,20000)
xlim = (0,200)
ylim = (-0.5,4)

figure, ax = plt.subplots(3, 3,figsize=(15, 15)) 

ax[0,0].plot(Au_Au_d_final_1800nm_1um, Au_Au_Shifted_Force_1800nm_1um, label='Au vs Au')
ax[0,0].plot(Si_BSG_d_final_100nm_1um, Si_BSG_Shifted_Force_100nm_1um, label='Si vs BSG')
ax[0,0].plot(Au_BSG_X1_d_final_1800nm_1um, Au_BSG_X1_Shifted_Force_1800nm_1um, label='Au vs BSG (X1)')
ax[0,0].plot(Au_BSG_X2_d_final_1800nm_1um, Au_BSG_X2_Shifted_Force_1800nm_1um, label='Au vs BSG (X2)')
ax[0,0].plot(Au_BSG_X3_d_final_1800nm_1um, Au_BSG_X3_Shifted_Force_1800nm_1um, label='Au vs BSG (X3)')
ax[0,0].scatter(d, Hydro_forces(1*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[0,0].set_title("1um/s")
ax[0,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,0].legend()
ax[0,0].grid()
ax[0,0].set_xlim(xlim)
ax[0,0].set_ylim(ylim)

ax[0,1].plot(Au_Au_d_final_1800nm_3um, Au_Au_Shifted_Force_1800nm_3um, label='Au vs Au')
#ax[0,1].plot(Si_BSG_d_final_100nm_3um, Si_BSG_Shifted_Force_100nm_3um, label='Si vs BSG')
ax[0,1].plot(Au_BSG_X1_d_final_1800nm_3um, Au_BSG_X1_Shifted_Force_1800nm_3um, label='Au vs BSG (X1)')
ax[0,1].plot(Au_BSG_X2_d_final_1800nm_3um, Au_BSG_X2_Shifted_Force_1800nm_3um, label='Au vs BSG (X2)')
ax[0,1].plot(Au_BSG_X3_d_final_1800nm_3um, Au_BSG_X3_Shifted_Force_1800nm_3um, label='Au vs BSG (X3)')
ax[0,1].scatter(d, Hydro_forces(3*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[0,1].set_title("3um/s")
ax[0,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,1].legend()
ax[0,1].grid()
ax[0,1].set_xlim(xlim)
ax[0,1].set_ylim(ylim)

ax[0,2].plot(Au_Au_d_final_1800nm_5um, Au_Au_Shifted_Force_1800nm_5um, label='Au vs Au')
ax[0,2].plot(Si_BSG_d_final_100nm_5um, Si_BSG_Shifted_Force_100nm_5um, label='Si vs BSG')
#ax[0,2].plot(Au_BSG_X1_d_final_1800nm_5um, Au_BSG_X1_Shifted_Force_1800nm_5um, label='Au vs BSG (X1)')
ax[0,2].plot(Au_BSG_X2_d_final_1800nm_5um, Au_BSG_X2_Shifted_Force_1800nm_5um, label='Au vs BSG (X2)')
ax[0,2].plot(Au_BSG_X3_d_final_1800nm_5um, Au_BSG_X3_Shifted_Force_1800nm_5um, label='Au vs BSG (X3)')
ax[0,2].scatter(d, Hydro_forces(5*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[0,2].set_title("5um/s")
ax[0,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,2].legend()
ax[0,2].grid()
ax[0,2].set_xlim(xlim)
ax[0,2].set_ylim(ylim)

ax[1,0].plot(Au_Au_d_final_1800nm_7um, Au_Au_Shifted_Force_1800nm_7um, label='Au vs Au')
ax[1,0].plot(Si_BSG_d_final_100nm_7um, Si_BSG_Shifted_Force_100nm_7um, label='Si vs BSG')
ax[1,0].plot(Au_BSG_X1_d_final_1800nm_7um, Au_BSG_X1_Shifted_Force_1800nm_7um, label='Au vs BSG (X1)')
ax[1,0].plot(Au_BSG_X2_d_final_1800nm_7um, Au_BSG_X2_Shifted_Force_1800nm_7um, label='Au vs BSG (X2)')
#ax[1,0].plot(Au_BSG_X3_d_final_1800nm_7um, Au_BSG_X3_Shifted_Force_1800nm_7um, label='Au vs BSG (X3)')
ax[1,0].scatter(d, Hydro_forces(7*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,0].set_title("7um/s")
ax[1,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,0].legend()
ax[1,0].grid()
ax[1,0].set_xlim(xlim)
ax[1,0].set_ylim(ylim)

ax[1,1].plot(Au_Au_d_final_1800nm_10um, Au_Au_Shifted_Force_1800nm_10um, label='Au vs Au')
ax[1,1].plot(Si_BSG_d_final_100nm_10um, Si_BSG_Shifted_Force_100nm_10um, label='Si vs BSG')
ax[1,1].plot(Au_BSG_X1_d_final_1800nm_10um, Au_BSG_X1_Shifted_Force_1800nm_10um, label='Au vs BSG (X1)')
ax[1,1].plot(Au_BSG_X2_d_final_1800nm_10um, Au_BSG_X2_Shifted_Force_1800nm_10um, label='Au vs BSG (X2)')
ax[1,1].plot(Au_BSG_X3_d_final_1800nm_10um, Au_BSG_X3_Shifted_Force_1800nm_10um, label='Au vs BSG (X3)')
ax[1,1].scatter(d, Hydro_forces(10*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,1].set_title("10um/s")
ax[1,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,1].legend()
ax[1,1].grid()
ax[1,1].set_xlim(xlim)
ax[1,1].set_ylim(ylim)

ax[1,2].plot(Au_Au_d_final_1800nm_15um, Au_Au_Shifted_Force_1800nm_15um, label='Au vs Au')
ax[1,2].plot(Si_BSG_d_final_100nm_15um, Si_BSG_Shifted_Force_100nm_15um, label='Si vs BSG')
ax[1,2].plot(Au_BSG_X1_d_final_1800nm_15um, Au_BSG_X1_Shifted_Force_1800nm_15um, label='Au vs BSG (X1)')
ax[1,2].plot(Au_BSG_X2_d_final_1800nm_15um, Au_BSG_X2_Shifted_Force_1800nm_15um, label='Au vs BSG (X2)')
ax[1,2].plot(Au_BSG_X3_d_final_1800nm_15um, Au_BSG_X3_Shifted_Force_1800nm_15um, label='Au vs BSG (X3)')
ax[1,2].scatter(d, Hydro_forces(15*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,2].set_title("15um/s")
ax[1,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,2].legend()
ax[1,2].grid()
ax[1,2].set_xlim(xlim)
ax[1,2].set_ylim(ylim)

ax[2,0].plot(Au_Au_d_final_1800nm_20um, Au_Au_Shifted_Force_1800nm_20um, label='Au vs Au')
ax[2,0].plot(Si_BSG_d_final_100nm_20um, Si_BSG_Shifted_Force_100nm_20um, label='Si vs BSG')
ax[2,0].plot(Au_BSG_X1_d_final_1800nm_20um, Au_BSG_X1_Shifted_Force_1800nm_20um, label='Au vs BSG (X1)')
ax[2,0].plot(Au_BSG_X2_d_final_1800nm_20um, Au_BSG_X2_Shifted_Force_1800nm_20um, label='Au vs BSG (X2)')
ax[2,0].plot(Au_BSG_X3_d_final_1800nm_20um, Au_BSG_X3_Shifted_Force_1800nm_20um, label='Au vs BSG (X3)')
ax[2,0].scatter(d, Hydro_forces(20*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,0].set_title("20um/s")
ax[2,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,0].legend()
ax[2,0].grid()
ax[2,0].set_xlim(xlim)
ax[2,0].set_ylim(ylim)

ax[2,1].plot(Au_Au_d_final_1800nm_500nm, Au_Au_Shifted_Force_1800nm_500nm, label='Au vs Au')
ax[2,1].plot(Si_BSG_d_final_100nm_500nm, Si_BSG_Shifted_Force_100nm_500nm, label='Si vs BSG')
ax[2,1].plot(Au_BSG_X1_d_final_1800nm_500nm, Au_BSG_X1_Shifted_Force_1800nm_500nm, label='Au vs BSG (X1)')
ax[2,1].plot(Au_BSG_X2_d_final_1800nm_500nm, Au_BSG_X2_Shifted_Force_1800nm_500nm, label='Au vs BSG (X2)')
ax[2,1].plot(Au_BSG_X3_d_final_1800nm_500nm, Au_BSG_X3_Shifted_Force_1800nm_500nm, label='Au vs BSG (X3)')
ax[2,1].scatter(d, Hydro_forces(0.5*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,1].set_title("500nm/s")
ax[2,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,1].legend()
ax[2,1].grid()
ax[2,1].set_xlim(xlim)
ax[2,1].set_ylim(ylim)

ax[2,2].plot(Au_Au_d_final_1800nm_800nm, Au_Au_Shifted_Force_1800nm_800nm, label='Au vs Au')
ax[2,2].plot(Si_BSG_d_final_100nm_800nm, Si_BSG_Shifted_Force_100nm_800nm, label='Si vs BSG')
ax[2,2].plot(Au_BSG_X1_d_final_1800nm_800nm, Au_BSG_X1_Shifted_Force_1800nm_800nm, label='Au vs BSG (X1)')
ax[2,2].plot(Au_BSG_X2_d_final_1800nm_800nm, Au_BSG_X2_Shifted_Force_1800nm_800nm, label='Au vs BSG (X2)')
ax[2,2].plot(Au_BSG_X3_d_final_1800nm_800nm, Au_BSG_X3_Shifted_Force_1800nm_800nm, label='Au vs BSG (X3)')
ax[2,2].scatter(d, Hydro_forces(0.8*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,2].set_title("800nm/s")
ax[2,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,2].legend()
ax[2,2].grid()
ax[2,2].set_xlim(xlim)
ax[2,2].set_ylim(ylim)

plt.show()
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_26212\1816072748.py:2: RuntimeWarning: divide by zero encountered in divide
#   return (v*6*math.pi*r**2*n)*10**12/(d*10**-9)

# %%
#Average X1 and X3 (5 and 7 are out)
X1_distance = [Au_BSG_X1_d_final_1800nm_500nm,Au_BSG_X1_d_final_1800nm_800nm,Au_BSG_X1_d_final_1800nm_1um,Au_BSG_X1_d_final_1800nm_3um,Au_BSG_X1_d_final_1800nm_10um,Au_BSG_X1_d_final_1800nm_15um,Au_BSG_X1_d_final_1800nm_20um]
X3_distance = [Au_BSG_X3_d_final_1800nm_500nm,Au_BSG_X3_d_final_1800nm_800nm,Au_BSG_X3_d_final_1800nm_1um,Au_BSG_X3_d_final_1800nm_3um,Au_BSG_X3_d_final_1800nm_10um,Au_BSG_X3_d_final_1800nm_15um,Au_BSG_X3_d_final_1800nm_20um]
Au_BSG_d_final_1800nm_500nm = []
Au_BSG_d_final_1800nm_800nm = []
Au_BSG_d_final_1800nm_1um = []
Au_BSG_d_final_1800nm_3um = []
Au_BSG_d_final_1800nm_10um = []
Au_BSG_d_final_1800nm_15um = []
Au_BSG_d_final_1800nm_20um = []
X1X3_distance = [Au_BSG_d_final_1800nm_500nm,Au_BSG_d_final_1800nm_800nm,Au_BSG_d_final_1800nm_1um,Au_BSG_d_final_1800nm_3um,Au_BSG_d_final_1800nm_10um,Au_BSG_d_final_1800nm_15um,Au_BSG_d_final_1800nm_20um]

for i in range(len(X1_distance)):
    for t in range(8702):
        X1X3_distance[i].append(stat.mean((X1_distance[i][t][0],X3_distance[i][t][0])))

X1_force = [Au_BSG_X1_Shifted_Force_1800nm_500nm,Au_BSG_X1_Shifted_Force_1800nm_800nm,Au_BSG_X1_Shifted_Force_1800nm_1um,Au_BSG_X1_Shifted_Force_1800nm_3um,Au_BSG_X1_Shifted_Force_1800nm_10um,Au_BSG_X1_Shifted_Force_1800nm_15um,Au_BSG_X1_Shifted_Force_1800nm_20um]
X3_force = [Au_BSG_X3_Shifted_Force_1800nm_500nm,Au_BSG_X3_Shifted_Force_1800nm_800nm,Au_BSG_X3_Shifted_Force_1800nm_1um,Au_BSG_X3_Shifted_Force_1800nm_3um,Au_BSG_X3_Shifted_Force_1800nm_10um,Au_BSG_X3_Shifted_Force_1800nm_15um,Au_BSG_X3_Shifted_Force_1800nm_20um]
Au_BSG_Shifted_Force_1800nm_500nm = []
Au_BSG_Shifted_Force_1800nm_800nm = []
Au_BSG_Shifted_Force_1800nm_1um = []
Au_BSG_Shifted_Force_1800nm_3um = []
Au_BSG_Shifted_Force_1800nm_10um = []
Au_BSG_Shifted_Force_1800nm_15um = []
Au_BSG_Shifted_Force_1800nm_20um = []
X1X3_force = [Au_BSG_Shifted_Force_1800nm_500nm,Au_BSG_Shifted_Force_1800nm_800nm,Au_BSG_Shifted_Force_1800nm_1um,Au_BSG_Shifted_Force_1800nm_3um,Au_BSG_Shifted_Force_1800nm_10um,Au_BSG_Shifted_Force_1800nm_15um,Au_BSG_Shifted_Force_1800nm_20um]

for i in range(len(X1_force)):
    for t in range(8702):
        X1X3_force[i].append(stat.mean((X1_force[i][t][0],X3_force[i][t][0])))
        
#Plot now
r = 10**-6 #radius of sphere
n = 0.0011439 #viscosity in Pa/s, for 20 degrees celcius
d = np.linspace(0,2000,20000)
xlim = (0,200)
ylim = (-0.5,4)

figure, ax = plt.subplots(3, 3,figsize=(15, 15)) 

ax[0,0].plot(Au_Au_d_final_1800nm_1um, Au_Au_Shifted_Force_1800nm_1um, label='Au vs Au')
ax[0,0].plot(Si_BSG_d_final_100nm_1um, Si_BSG_Shifted_Force_100nm_1um, label='Si vs BSG')
ax[0,0].plot(X1X3_distance[2],X1X3_force[2], label='Au vs BSG')
ax[0,0].scatter(d, Hydro_forces(1*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[0,0].set_title("1um/s")
ax[0,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,0].legend()
ax[0,0].grid()
ax[0,0].set_xlim(xlim)
ax[0,0].set_ylim(ylim)

ax[0,1].plot(Au_Au_d_final_1800nm_3um, Au_Au_Shifted_Force_1800nm_3um, label='Au vs Au')
#ax[0,1].plot(Si_BSG_d_final_100nm_3um, Si_BSG_Shifted_Force_100nm_3um, label='Si vs BSG')
ax[0,1].plot(X1X3_distance[3],X1X3_force[3], label='Au vs BSG')
ax[0,1].scatter(d, Hydro_forces(3*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[0,1].set_title("3um/s")
ax[0,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[0,1].legend()
ax[0,1].grid()
ax[0,1].set_xlim(xlim)
ax[0,1].set_ylim(ylim)

ax[1,1].plot(Au_Au_d_final_1800nm_10um, Au_Au_Shifted_Force_1800nm_10um, label='Au vs Au')
ax[1,1].plot(Si_BSG_d_final_100nm_10um, Si_BSG_Shifted_Force_100nm_10um, label='Si vs BSG')
ax[1,1].plot(X1X3_distance[4],X1X3_force[4], label='Au vs BSG')
ax[1,1].scatter(d, Hydro_forces(10*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,1].set_title("10um/s")
ax[1,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,1].legend()
ax[1,1].grid()
ax[1,1].set_xlim(xlim)
ax[1,1].set_ylim(ylim)

ax[1,2].plot(Au_Au_d_final_1800nm_15um, Au_Au_Shifted_Force_1800nm_15um, label='Au vs Au')
ax[1,2].plot(Si_BSG_d_final_100nm_15um, Si_BSG_Shifted_Force_100nm_15um, label='Si vs BSG')
ax[1,2].plot(X1X3_distance[5],X1X3_force[5], label='Au vs BSG')
ax[1,2].scatter(d, Hydro_forces(15*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[1,2].set_title("15um/s")
ax[1,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[1,2].legend()
ax[1,2].grid()
ax[1,2].set_xlim(xlim)
ax[1,2].set_ylim(ylim)

ax[2,0].plot(Au_Au_d_final_1800nm_20um, Au_Au_Shifted_Force_1800nm_20um, label='Au vs Au')
ax[2,0].plot(Si_BSG_d_final_100nm_20um, Si_BSG_Shifted_Force_100nm_20um, label='Si vs BSG')
ax[2,0].plot(X1X3_distance[6],X1X3_force[6], label='Au vs BSG')
ax[2,0].scatter(d, Hydro_forces(20*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,0].set_title("20um/s")
ax[2,0].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,0].legend()
ax[2,0].grid()
ax[2,0].set_xlim(xlim)
ax[2,0].set_ylim(ylim)

ax[2,1].plot(Au_Au_d_final_1800nm_500nm, Au_Au_Shifted_Force_1800nm_500nm, label='Au vs Au')
ax[2,1].plot(Si_BSG_d_final_100nm_500nm, Si_BSG_Shifted_Force_100nm_500nm, label='Si vs BSG')
ax[2,1].plot(X1X3_distance[0],X1X3_force[0], label='Au vs BSG')
ax[2,1].scatter(d, Hydro_forces(0.5*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,1].set_title("500nm/s")
ax[2,1].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,1].legend()
ax[2,1].grid()
ax[2,1].set_xlim(xlim)
ax[2,1].set_ylim(ylim)

ax[2,2].plot(Au_Au_d_final_1800nm_800nm, Au_Au_Shifted_Force_1800nm_800nm, label='Au vs Au')
ax[2,2].plot(Si_BSG_d_final_100nm_800nm, Si_BSG_Shifted_Force_100nm_800nm, label='Si vs BSG')
ax[2,2].plot(X1X3_distance[1],X1X3_force[1], label='Au vs BSG')
ax[2,2].scatter(d, Hydro_forces(0.8*10**-6,d,r,n), c='red', s=0.5, label='clasical')
ax[2,2].set_title("800nm/s")
ax[2,2].set(xlabel='Separation (nm)', ylabel='Force (nN)')
ax[2,2].legend()
ax[2,2].grid()
ax[2,2].set_xlim(xlim)
ax[2,2].set_ylim(ylim)

plt.show()
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\1816072748.py:2: RuntimeWarning: divide by zero encountered in divide
#   return (v*6*math.pi*r**2*n)*10**12/(d*10**-9)

# %% [markdown]
# ### Determine the slip length for 1um/s

# %%
### RUN ONLY ONCE!! 


#Take out 0.0 values for Au_Au
Au_Au_positions_of_zeros_in_Force = [7137]

print(len(Au_Au_Shifted_Force_1800nm_1um))
print(len(Au_Au_d_final_1800nm_1um))
for positions in Au_Au_positions_of_zeros_in_Force:
    Au_Au_Shifted_Force_1800nm_1um.pop(positions)
    Au_Au_d_final_1800nm_1um.pop(positions)
print(len(Au_Au_Shifted_Force_1800nm_1um))
print(len(Au_Au_d_final_1800nm_1um))

#Take out 0.0 values for Si_BSG
Si_BSG_positions_of_zeros_in_Force = [5469]

print(len(Si_BSG_Shifted_Force_100nm_1um))
print(len(Si_BSG_d_final_100nm_1um))
for positions in Si_BSG_positions_of_zeros_in_Force:
    Si_BSG_Shifted_Force_100nm_1um.pop(positions)
    Si_BSG_d_final_100nm_1um.pop(positions)
print(len(Si_BSG_Shifted_Force_100nm_1um))
print(len(Si_BSG_d_final_100nm_1um))

#Take out 0.0 values for Au_BSG_X1
Au_BSG_X1_positions_of_zeros_in_Force = [7588]

print(len(Au_BSG_X1_Shifted_Force_1800nm_1um))
print(len(Au_BSG_X1_d_final_1800nm_1um))
for positions in Au_BSG_X1_positions_of_zeros_in_Force:
    Au_BSG_X1_Shifted_Force_1800nm_1um.pop(positions)
    Au_BSG_X1_d_final_1800nm_1um.pop(positions)
print(len(Au_BSG_X1_Shifted_Force_1800nm_1um))
print(len(Au_BSG_X1_d_final_1800nm_1um))

#Take out 0.0 values for Au_BSG_X2
Au_BSG_X2_positions_of_zeros_in_Force = [8306]

print(len(Au_BSG_X2_Shifted_Force_1800nm_1um))
print(len(Au_BSG_X2_d_final_1800nm_1um))
for positions in Au_BSG_X2_positions_of_zeros_in_Force:
    Au_BSG_X2_Shifted_Force_1800nm_1um.pop(positions)
    Au_BSG_X2_d_final_1800nm_1um.pop(positions)
print(len(Au_BSG_X2_Shifted_Force_1800nm_1um))
print(len(Au_BSG_X2_d_final_1800nm_1um))

#Take out 0.0 values for Au_BSG_X3
Au_BSG_X3_positions_of_zeros_in_Force = [8350,8352]

print(len(Au_BSG_X3_Shifted_Force_1800nm_1um))
print(len(Au_BSG_X3_d_final_1800nm_1um))
for positions in Au_BSG_X3_positions_of_zeros_in_Force:
    Au_BSG_X3_Shifted_Force_1800nm_1um.pop(positions)
    Au_BSG_X3_d_final_1800nm_1um.pop(positions)
print(len(Au_BSG_X3_Shifted_Force_1800nm_1um))
print(len(Au_BSG_X3_d_final_1800nm_1um))

# %%
#V/F against 1/d to fit the function from theory
max_range = 8500

def slip_length(v,F):
    vF = []
    for i in range(0,max_range):       # the -1 on the len(F) is to take the last value of the distance for 200nm that is 0
        x = v/(F[i][0])
        vF.append(x)
    return vF

def inverse_distance(d):
    d_inverse = []
    for i in range(0,max_range):       # the -1 on the len(d) is to take the last value of the distance for 200nm that is 0
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

plt.title("1um/s")
plt.scatter(inverse_distance(Au_Au_d_final_1800nm_1um),slip_length(10.0,Au_Au_Shifted_Force_1800nm_1um), label='200nm', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(inverse_distance(Si_BSG_d_final_100nm_1um),slip_length(10.0,Si_BSG_Shifted_Force_100nm_1um), label='200nm', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(inverse_distance(Au_BSG_X1_d_final_1800nm_1um),slip_length(10.0,Au_BSG_X1_Shifted_Force_1800nm_1um), label='200nm', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(inverse_distance(Au_BSG_X2_d_final_1800nm_1um),slip_length(10.0,Au_BSG_X2_Shifted_Force_1800nm_1um), label='200nm', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(inverse_distance(Au_BSG_X3_d_final_1800nm_1um),slip_length(10.0,Au_BSG_X3_Shifted_Force_1800nm_1um), label='200nm', s=5)  #s is the parameter for the size of the scattered points
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
plt.ylim(-1, 4000)
plt.grid()
plt.show()

# %%
#V/F against 1/d to fit the function from theory
import numpy as np
from sklearn.linear_model import LinearRegression
max_range = 7000

def slip_length(v,F):
    vF = []
    for i in range(0,max_range):       
        x = v/(F[i][0])
        vF.append(x)
    return vF

def inverse_distance(d):
    d_inverse = []
    for i in range(0,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_1um)).reshape((-1,1)), np.array(slip_length(10.0,Au_Au_Shifted_Force_1800nm_1um))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_1um)).reshape((-1,1)), np.array(slip_length(10.0,Si_BSG_Shifted_Force_100nm_1um))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_1um)).reshape((-1,1)), np.array(slip_length(10.0,Au_BSG_X1_Shifted_Force_1800nm_1um))]
args_Au_BSG_X2 = [np.array(inverse_distance(Au_BSG_X2_d_final_1800nm_1um)).reshape((-1,1)), np.array(slip_length(10.0,Au_BSG_X2_Shifted_Force_1800nm_1um))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_1um)).reshape((-1,1)), np.array(slip_length(10.0,Au_BSG_X3_Shifted_Force_1800nm_1um))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au = model_Au_Au.intercept_
slope_Au_Au = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG = model_Si_BSG.intercept_
slope_Si_BSG = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1 = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1 = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1 = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X2
model_Au_BSG_X2 = LinearRegression().fit(args_Au_BSG_X2[0],args_Au_BSG_X2[1])
r_sq_Au_BSG_X2 = model_Au_BSG_X2.score(args_Au_BSG_X2[0],args_Au_BSG_X2[1])
intercept_Au_BSG_X2 = model_Au_BSG_X2.intercept_
slope_Au_BSG_X2 = model_Au_BSG_X2.coef_
y_pred_Au_BSG_X2 = model_Au_BSG_X2.predict(args_Au_BSG_X2[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3 = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3 = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3 = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])


#Plotting
plt.title("10um/s for d_0")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X2[0],args_Au_BSG_X2[1], label='Au vs BSG X2', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1}')
plt.plot(args_Au_BSG_X2[0], y_pred_Au_BSG_X2, label=f'slip length: {intercept_Au_BSG_X2}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3}')
plt.xlabel("1/Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
plt.xlim(0.0005, 0.002)
plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au}")
print(f"The intercept is of: {intercept_Au_Au}")
print(f"The determination coefficient is of: {r_sq_Au_Au}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG}")
print(f"The intercept is of: {intercept_Si_BSG}")
print(f"The determination coefficient is of: {r_sq_Si_BSG}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1}")
print(f"The intercept is of: {intercept_Au_BSG_X1}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1}")
print("For Au vs BSG X2")
print(f"The slope is of: {slope_Au_BSG_X2}")
print(f"The intercept is of: {intercept_Au_BSG_X2}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X2}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3}")
print(f"The intercept is of: {intercept_Au_BSG_X3}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3}")
# Out:
# For Au_Au
# The slope is of: [60852.94416652]
# The intercept is of: 75.29033148641454
# The determination coefficient is of: 0.1366254141174047
# For Si_BSG
# The slope is of: [162101.49581607]
# The intercept is of: 511.81913348573784
# The determination coefficient is of: 0.07370401648130676
# For Au vs BSG X1
# The slope is of: [30176.47210019]
# The intercept is of: 331.5021660433474
# The determination coefficient is of: 0.03935266188441655
# For Au vs BSG X2
# The slope is of: [27.20849274]
# The intercept is of: 6.243768671429765
# The determination coefficient is of: 0.45210579876020973
# For Au vs BSG X3
# The slope is of: [15210.48745214]
# The intercept is of: 213.31366261597915
# The determination coefficient is of: 0.12553926420389838

# %% [markdown]
# ### MARK THE LAST LINEAR LEFT POINTS

# %%
#AU VS AU 1UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_1um[8450], Au_Au_d_final_1800nm_1um[8700]]
y_0 = [Au_Au_Shifted_Force_1800nm_1um[8450], Au_Au_Shifted_Force_1800nm_1um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_1um[8000], Au_Au_d_final_1800nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_1um)):
    sep.append(Au_Au_d_final_1800nm_1um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_1um)):
    sep.append(Au_Au_d_final_1800nm_1um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_1um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 20

# %%
#AU VS AU 3UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_3um[8450], Au_Au_d_final_1800nm_3um[8600]]
y_0 = [Au_Au_Shifted_Force_1800nm_3um[8450], Au_Au_Shifted_Force_1800nm_3um[8600]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_3um[8000], Au_Au_d_final_1800nm_3um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_3um)):
    sep.append(Au_Au_d_final_1800nm_3um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_3um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_3um)):
    sep.append(Au_Au_d_final_1800nm_3um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_3um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 20.5

# %%
#AU VS AU 5UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_5um[8450], Au_Au_d_final_1800nm_5um[8600]]
y_0 = [Au_Au_Shifted_Force_1800nm_5um[8450], Au_Au_Shifted_Force_1800nm_5um[8600]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_5um[8000], Au_Au_d_final_1800nm_5um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_5um)):
    sep.append(Au_Au_d_final_1800nm_5um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_5um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_5um)):
    sep.append(Au_Au_d_final_1800nm_5um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_5um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 19.5

# %%
#AU VS AU 7UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_7um[8450], Au_Au_d_final_1800nm_7um[8600]]
y_0 = [Au_Au_Shifted_Force_1800nm_7um[8450], Au_Au_Shifted_Force_1800nm_7um[8600]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_7um[8000], Au_Au_d_final_1800nm_7um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_7um)):
    sep.append(Au_Au_d_final_1800nm_7um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_7um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_7um)):
    sep.append(Au_Au_d_final_1800nm_7um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_7um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 19

# %%
#AU VS AU 10UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_10um[8600], Au_Au_d_final_1800nm_10um[8700]]
y_0 = [Au_Au_Shifted_Force_1800nm_10um[8600], Au_Au_Shifted_Force_1800nm_10um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_10um[8000], Au_Au_d_final_1800nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_10um)):
    sep.append(Au_Au_d_final_1800nm_10um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_10um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_10um)):
    sep.append(Au_Au_d_final_1800nm_10um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_10um)
plt.xlim(6,12)
plt.ylim(-1,7)
plt.show()
#From the left: 7.5

# %%
#AU VS AU 15UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_15um[8600], Au_Au_d_final_1800nm_15um[8700]]
y_0 = [Au_Au_Shifted_Force_1800nm_15um[8600], Au_Au_Shifted_Force_1800nm_15um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_15um[8000], Au_Au_d_final_1800nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_15um)):
    sep.append(Au_Au_d_final_1800nm_15um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_15um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_15um)):
    sep.append(Au_Au_d_final_1800nm_15um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_15um)
plt.xlim(4,10)
plt.ylim(-1,7)
plt.show()
#From the left: 8

# %%
#AU VS AU 20UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_20um[8080], Au_Au_d_final_1800nm_20um[8180]]
y_0 = [Au_Au_Shifted_Force_1800nm_20um[8080], Au_Au_Shifted_Force_1800nm_20um[8180]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_20um[8000], Au_Au_d_final_1800nm_20um[8180],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_20um)):
    sep.append(Au_Au_d_final_1800nm_20um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_20um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_20um)):
    sep.append(Au_Au_d_final_1800nm_20um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_20um)
plt.xlim(22,30)
plt.ylim(-1,7)
plt.show()
#From the left: 28

# %%
#AU VS AU 500nM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_500nm[8300], Au_Au_d_final_1800nm_500nm[8680]]
y_0 = [Au_Au_Shifted_Force_1800nm_500nm[8300], Au_Au_Shifted_Force_1800nm_500nm[8680]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_500nm[8000], Au_Au_d_final_1800nm_500nm[8680],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_500nm)):
    sep.append(Au_Au_d_final_1800nm_500nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_500nm)):
    sep.append(Au_Au_d_final_1800nm_500nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_500nm)
plt.xlim(22,30)
plt.ylim(-1,7)
plt.show()
#From the left: 29

# %%
#AU VS AU 800nM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_800nm[8100], Au_Au_d_final_1800nm_800nm[8180]]
y_0 = [Au_Au_Shifted_Force_1800nm_800nm[8100], Au_Au_Shifted_Force_1800nm_800nm[8180]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_800nm[8000], Au_Au_d_final_1800nm_800nm[8180],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_800nm)):
    sep.append(Au_Au_d_final_1800nm_800nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_800nm)):
    sep.append(Au_Au_d_final_1800nm_800nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_800nm)
plt.xlim(22,30)
plt.ylim(-1,7)
plt.show()
#From the left: 24

# %%
#SI VS BSG 1UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_1um[8650], Si_BSG_d_final_100nm_1um[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_1um[8650], Si_BSG_Shifted_Force_100nm_1um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_1um[8000], Si_BSG_d_final_100nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_1um)):
    sep.append(Si_BSG_d_final_100nm_1um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_1um)):
    sep.append(Si_BSG_d_final_100nm_1um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_1um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 20.5

# %%
#SI VS BSG 5UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_5um[8650], Si_BSG_d_final_100nm_5um[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_5um[8650], Si_BSG_Shifted_Force_100nm_5um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_5um[8000], Si_BSG_d_final_100nm_5um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_5um)):
    sep.append(Si_BSG_d_final_100nm_5um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_5um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_5um)):
    sep.append(Si_BSG_d_final_100nm_5um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_5um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 22

# %%
#SI VS BSG 7UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_7um[8650], Si_BSG_d_final_100nm_7um[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_7um[8650], Si_BSG_Shifted_Force_100nm_7um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_7um[8000], Si_BSG_d_final_100nm_7um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_7um)):
    sep.append(Si_BSG_d_final_100nm_7um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_7um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_7um)):
    sep.append(Si_BSG_d_final_100nm_7um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_7um)
plt.xlim(19,23)
plt.ylim(-1,7)
plt.show()
#From the left: 21.5

# %%
#SI VS BSG 10UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_10um[8650], Si_BSG_d_final_100nm_10um[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_10um[8650], Si_BSG_Shifted_Force_100nm_10um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_10um[8000], Si_BSG_d_final_100nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_10um)):
    sep.append(Si_BSG_d_final_100nm_10um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_10um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_10um)):
    sep.append(Si_BSG_d_final_100nm_10um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_10um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 20

# %%
#SI VS BSG 15UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_15um[8650], Si_BSG_d_final_100nm_15um[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_15um[8650], Si_BSG_Shifted_Force_100nm_15um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_15um[8000], Si_BSG_d_final_100nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_15um)):
    sep.append(Si_BSG_d_final_100nm_15um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_15um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_15um)):
    sep.append(Si_BSG_d_final_100nm_15um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_15um)
plt.xlim(17,21)
plt.ylim(-1,7)
plt.show()
#From the left: 18.5

# %%
#SI VS BSG 20UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_20um[8650], Si_BSG_d_final_100nm_20um[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_20um[8650], Si_BSG_Shifted_Force_100nm_20um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_20um[8000], Si_BSG_d_final_100nm_20um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_20um)):
    sep.append(Si_BSG_d_final_100nm_20um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_20um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_20um)):
    sep.append(Si_BSG_d_final_100nm_20um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_20um)
plt.xlim(16,23)
plt.ylim(-1,7)
plt.show()
#From the left: 20

# %%
#SI VS BSG 500NM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_500nm[8650], Si_BSG_d_final_100nm_500nm[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_500nm[8650], Si_BSG_Shifted_Force_100nm_500nm[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_500nm[8000], Si_BSG_d_final_100nm_500nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_500nm)):
    sep.append(Si_BSG_d_final_100nm_500nm[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_500nm)):
    sep.append(Si_BSG_d_final_100nm_500nm[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_500nm)
plt.xlim(17,20)
plt.ylim(-1,7)
plt.show()
#From the left: 18.5

# %%
#SI VS BSG 800NM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_800nm[8650], Si_BSG_d_final_100nm_800nm[8700]]
y_0 = [Si_BSG_Shifted_Force_100nm_800nm[8650], Si_BSG_Shifted_Force_100nm_800nm[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_800nm[8000], Si_BSG_d_final_100nm_800nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_800nm)):
    sep.append(Si_BSG_d_final_100nm_800nm[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_800nm)):
    sep.append(Si_BSG_d_final_100nm_800nm[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_800nm)
plt.xlim(17,20)
plt.ylim(-1,7)
plt.show()
#From the left: 18.5

# %%
#AU VS BSG (X1) 1UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_1um[8450], Au_BSG_X1_d_final_1800nm_1um[8700]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_1um[8450], Au_BSG_X1_Shifted_Force_1800nm_1um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_1um[8000], Au_BSG_X1_d_final_1800nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_1um)):
    sep.append(Au_BSG_X1_d_final_1800nm_1um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_1um)):
    sep.append(Au_BSG_X1_d_final_1800nm_1um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_1um)
plt.xlim(33.5,35)
plt.ylim(-1,7)
plt.show()
#From the left: 35

# %%
#AU VS BSG (X1) 3UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_3um[8450], Au_BSG_X1_d_final_1800nm_3um[8700]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_3um[8450], Au_BSG_X1_Shifted_Force_1800nm_3um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_3um[8000], Au_BSG_X1_d_final_1800nm_3um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_3um)):
    sep.append(Au_BSG_X1_d_final_1800nm_3um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_3um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_3um)):
    sep.append(Au_BSG_X1_d_final_1800nm_3um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_3um)
plt.xlim(28,33)
plt.ylim(-1,7)
plt.show()
#From the left: 31.5

# %%
#AU VS BSG (X1) 7UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_7um[8450], Au_BSG_X1_d_final_1800nm_7um[8700]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_7um[8450], Au_BSG_X1_Shifted_Force_1800nm_7um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_7um[8000], Au_BSG_X1_d_final_1800nm_7um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_7um)):
    sep.append(Au_BSG_X1_d_final_1800nm_7um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_7um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_7um)):
    sep.append(Au_BSG_X1_d_final_1800nm_7um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_7um)
plt.xlim(32,38)
plt.ylim(1,4)
plt.show()
#From the left: 33

# %%
#AU VS BSG (X1) 10UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_10um[8450], Au_BSG_X1_d_final_1800nm_10um[8700]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_10um[8450], Au_BSG_X1_Shifted_Force_1800nm_10um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_10um[8000], Au_BSG_X1_d_final_1800nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_10um)):
    sep.append(Au_BSG_X1_d_final_1800nm_10um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_10um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_10um)):
    sep.append(Au_BSG_X1_d_final_1800nm_10um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_10um)
plt.xlim(40,46)
plt.ylim(0,2)
plt.show()
#From the left: 41.5

# %%
#AU VS BSG (X1) 15UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_15um[8280], Au_BSG_X1_d_final_1800nm_15um[8400]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_15um[8280], Au_BSG_X1_Shifted_Force_1800nm_15um[8400]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_15um[8000], Au_BSG_X1_d_final_1800nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_15um)):
    sep.append(Au_BSG_X1_d_final_1800nm_15um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_15um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_15um)):
    sep.append(Au_BSG_X1_d_final_1800nm_15um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_15um)
plt.xlim(38,55)
plt.ylim(0,3)
plt.show()
#From the left: 49

# %%
#AU VS BSG (X1) 20UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_20um[8280], Au_BSG_X1_d_final_1800nm_20um[8400]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_20um[8280], Au_BSG_X1_Shifted_Force_1800nm_20um[8400]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_20um[8000], Au_BSG_X1_d_final_1800nm_20um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_20um)):
    sep.append(Au_BSG_X1_d_final_1800nm_20um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_20um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_20um)):
    sep.append(Au_BSG_X1_d_final_1800nm_20um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_20um)
plt.xlim(46,52)
plt.ylim(0,3)
plt.show()
#From the left: 49

# %%
#AU VS BSG (X1) 500NM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_500nm[8280], Au_BSG_X1_d_final_1800nm_500nm[8400]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_500nm[8280], Au_BSG_X1_Shifted_Force_1800nm_500nm[8400]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_500nm[8000], Au_BSG_X1_d_final_1800nm_500nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_500nm[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_500nm[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_500nm)
plt.xlim(46,52)
plt.ylim(0,3)
plt.show()
#From the left: 50

# %%
#AU VS BSG (X1) 800NM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_800nm[8280], Au_BSG_X1_d_final_1800nm_800nm[8400]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_800nm[8280], Au_BSG_X1_Shifted_Force_1800nm_800nm[8400]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_800nm[8000], Au_BSG_X1_d_final_1800nm_800nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_800nm[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_800nm[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_800nm)
plt.xlim(46,52)
plt.ylim(0,3)
plt.show()
#From the left: 50

# %%
#AU VS BSG (X3) 1UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_1um[8450], Au_BSG_X3_d_final_1800nm_1um[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_1um[8450], Au_BSG_X3_Shifted_Force_1800nm_1um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_1um[8000], Au_BSG_X3_d_final_1800nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_1um)):
    sep.append(Au_BSG_X3_d_final_1800nm_1um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_1um)):
    sep.append(Au_BSG_X3_d_final_1800nm_1um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_1um)
plt.xlim(30,40)
plt.ylim(-1,7)
plt.show()
#From the left: 35

# %%
#AU VS BSG (X3) 3UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_3um[8450], Au_BSG_X3_d_final_1800nm_3um[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_3um[8450], Au_BSG_X3_Shifted_Force_1800nm_3um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_3um[8000], Au_BSG_X3_d_final_1800nm_3um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_3um)):
    sep.append(Au_BSG_X3_d_final_1800nm_3um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_3um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_3um)):
    sep.append(Au_BSG_X3_d_final_1800nm_3um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_3um)
plt.xlim(30,40)
plt.ylim(-1,7)
plt.show()
#From the left: 31

# %%
#AU VS BSG (X3) 5UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_5um[8500], Au_BSG_X3_d_final_1800nm_5um[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_5um[8500], Au_BSG_X3_Shifted_Force_1800nm_5um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_5um[8000], Au_BSG_X3_d_final_1800nm_5um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_5um)):
    sep.append(Au_BSG_X3_d_final_1800nm_5um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_5um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_5um)):
    sep.append(Au_BSG_X3_d_final_1800nm_5um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_5um)
plt.xlim(20,30)
plt.ylim(1,4)
plt.show()
#From the left: 25

# %%
#AU VS BSG (X3) 10UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_10um[8500], Au_BSG_X3_d_final_1800nm_10um[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_10um[8500], Au_BSG_X3_Shifted_Force_1800nm_10um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_10um[8000], Au_BSG_X3_d_final_1800nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_10um)):
    sep.append(Au_BSG_X3_d_final_1800nm_10um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_10um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_10um)):
    sep.append(Au_BSG_X3_d_final_1800nm_10um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_10um)
plt.xlim(20,30)
plt.ylim(1,4)
plt.show()
#From the left: 25

# %%
#AU VS BSG (X3) 15UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_15um[8450], Au_BSG_X3_d_final_1800nm_15um[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_15um[8450], Au_BSG_X3_Shifted_Force_1800nm_15um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_15um[8000], Au_BSG_X3_d_final_1800nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_15um)):
    sep.append(Au_BSG_X3_d_final_1800nm_15um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_15um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_15um)):
    sep.append(Au_BSG_X3_d_final_1800nm_15um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_15um)
plt.xlim(30,40)
plt.ylim(-1,7)
plt.show()
#From the left: 34

# %%
#AU VS BSG (X3) 20UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_20um[8450], Au_BSG_X3_d_final_1800nm_20um[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_20um[8450], Au_BSG_X3_Shifted_Force_1800nm_20um[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_20um[8000], Au_BSG_X3_d_final_1800nm_20um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_20um)):
    sep.append(Au_BSG_X3_d_final_1800nm_20um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_20um)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_20um)):
    sep.append(Au_BSG_X3_d_final_1800nm_20um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_20um)
plt.xlim(30,40)
plt.ylim(-1,7)
plt.show()
#From the left: 32

# %%
#AU VS BSG (X3) 500NM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_500nm[8450], Au_BSG_X3_d_final_1800nm_500nm[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_500nm[8450], Au_BSG_X3_Shifted_Force_1800nm_500nm[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_500nm[8000], Au_BSG_X3_d_final_1800nm_500nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_500nm[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_500nm[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_500nm)
plt.xlim(30,34)
plt.ylim(-1,2)
plt.show()
#From the left: 32.5

# %%
#AU VS BSG (X3) 800NM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_800nm[8450], Au_BSG_X3_d_final_1800nm_800nm[8700]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_800nm[8450], Au_BSG_X3_Shifted_Force_1800nm_800nm[8700]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_800nm[8000], Au_BSG_X3_d_final_1800nm_800nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_800nm[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,8)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_800nm[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_800nm)
plt.xlim(30,34)
plt.ylim(-1,2)
plt.show()
#From the left: 33

# %% [markdown]
# ### MARK THE LAST LINEAR RIGHT POINTS

# %%
#AU VS AU 1UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_1um[0], Au_Au_d_final_1800nm_1um[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_1um[0], Au_Au_Shifted_Force_1800nm_1um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_1um[8000], Au_Au_d_final_1800nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_1um)):
    sep.append(Au_Au_d_final_1800nm_1um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_1um)):
    sep.append(Au_Au_d_final_1800nm_1um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_1um)
plt.xlim(30,45)
plt.ylim(-1,1)
plt.show()
#From the right: 37

# %%
#AU VS AU 3UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_3um[0], Au_Au_d_final_1800nm_3um[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_3um[0], Au_Au_Shifted_Force_1800nm_3um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_3um[0], Au_Au_d_final_1800nm_3um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_3um)):
    sep.append(Au_Au_d_final_1800nm_3um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_3um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_3um)):
    sep.append(Au_Au_d_final_1800nm_3um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_3um)
plt.xlim(35,70)
plt.ylim(-1,6)
plt.show()
#From the right: 40

# %%
#AU VS AU 5UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_5um[0], Au_Au_d_final_1800nm_5um[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_5um[0], Au_Au_Shifted_Force_1800nm_5um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_5um[0], Au_Au_d_final_1800nm_5um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_5um)):
    sep.append(Au_Au_d_final_1800nm_5um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_5um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_5um)):
    sep.append(Au_Au_d_final_1800nm_5um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_5um)
plt.xlim(35,45)
plt.ylim(-1,7)
plt.show()
#From the right: 43

# %%
#AU VS AU 7UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_7um[0], Au_Au_d_final_1800nm_7um[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_7um[0], Au_Au_Shifted_Force_1800nm_7um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_7um[0], Au_Au_d_final_1800nm_7um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_7um)):
    sep.append(Au_Au_d_final_1800nm_7um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_7um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_7um)):
    sep.append(Au_Au_d_final_1800nm_7um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_7um)
plt.xlim(30,45)
plt.ylim(-1,7)
plt.show()
#From the right: 38

# %%
#AU VS AU 10UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_10um[0], Au_Au_d_final_1800nm_10um[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_10um[0], Au_Au_Shifted_Force_1800nm_10um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_10um[0], Au_Au_d_final_1800nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_10um)):
    sep.append(Au_Au_d_final_1800nm_10um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_10um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_10um)):
    sep.append(Au_Au_d_final_1800nm_10um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_10um)
plt.xlim(5,18)
plt.ylim(-1,7)
plt.show()
#From the right: 11

# %%
#AU VS AU 15UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_15um[0], Au_Au_d_final_1800nm_15um[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_15um[0], Au_Au_Shifted_Force_1800nm_15um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_15um[0], Au_Au_d_final_1800nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_15um)):
    sep.append(Au_Au_d_final_1800nm_15um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_15um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_15um)):
    sep.append(Au_Au_d_final_1800nm_15um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_15um)
plt.xlim(120,140)
plt.ylim(-1,2)
plt.show()
#From the right: 130

# %%
#AU VS AU 20UM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_20um[2000], Au_Au_d_final_1800nm_20um[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_20um[2000], Au_Au_Shifted_Force_1800nm_20um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_20um[0], Au_Au_d_final_1800nm_20um[8100],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_20um)):
    sep.append(Au_Au_d_final_1800nm_20um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_20um)
#plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_20um)):
    sep.append(Au_Au_d_final_1800nm_20um[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_20um)
plt.xlim(200,450)
plt.ylim(-1,2)
plt.show()
#From the right: 400

# %%
#AU VS AU 500NM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_500nm[0], Au_Au_d_final_1800nm_500nm[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_500nm[0], Au_Au_Shifted_Force_1800nm_500nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_500nm[0], Au_Au_d_final_1800nm_500nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_500nm)):
    sep.append(Au_Au_d_final_1800nm_500nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_500nm)):
    sep.append(Au_Au_d_final_1800nm_500nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_500nm)
plt.xlim(30,42)
plt.ylim(-1,2)
plt.show()
#From the right: 41

# %%
#AU VS AU 800NM
# Define the known points 
x_0 = [Au_Au_d_final_1800nm_800nm[0], Au_Au_d_final_1800nm_800nm[5000]]
y_0 = [Au_Au_Shifted_Force_1800nm_800nm[0], Au_Au_Shifted_Force_1800nm_800nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_Au_d_final_1800nm_800nm[0], Au_Au_d_final_1800nm_800nm[8100],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_800nm)):
    sep.append(Au_Au_d_final_1800nm_800nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_Au_d_final_1800nm_800nm)):
    sep.append(Au_Au_d_final_1800nm_800nm[i])
plt.plot(sep, Au_Au_Shifted_Force_1800nm_800nm)
plt.xlim(28,35)
plt.ylim(-1,2)
plt.show()
#From the right: 31

# %%
#SI VS BSG 1UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_1um[0], Si_BSG_d_final_100nm_1um[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_1um[0], Si_BSG_Shifted_Force_100nm_1um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_1um[8000], Si_BSG_d_final_100nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_1um)):
    sep.append(Si_BSG_d_final_100nm_1um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_1um)):
    sep.append(Si_BSG_d_final_100nm_1um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_1um)
plt.xlim(30,100)
plt.ylim(-1,7)
plt.show()
#From the right: 50

# %%
#SI VS BSG 5UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_5um[0], Si_BSG_d_final_100nm_5um[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_5um[0], Si_BSG_Shifted_Force_100nm_5um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_5um[0], Si_BSG_d_final_100nm_5um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_5um)):
    sep.append(Si_BSG_d_final_100nm_5um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_5um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_5um)):
    sep.append(Si_BSG_d_final_100nm_5um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_5um)
plt.xlim(30,300)
plt.ylim(-1,1)
plt.show()
#From the right: 225

# %%
#SI VS BSG 7UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_7um[0], Si_BSG_d_final_100nm_7um[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_7um[0], Si_BSG_Shifted_Force_100nm_7um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_7um[0], Si_BSG_d_final_100nm_7um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_7um)):
    sep.append(Si_BSG_d_final_100nm_7um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_7um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_7um)):
    sep.append(Si_BSG_d_final_100nm_7um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_7um)
plt.xlim(240,375)
plt.ylim(-1,1)
plt.show()
#From the right: 300

# %%
#SI VS BSG 10UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_10um[0], Si_BSG_d_final_100nm_10um[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_10um[0], Si_BSG_Shifted_Force_100nm_10um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_10um[0], Si_BSG_d_final_100nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_10um)):
    sep.append(Si_BSG_d_final_100nm_10um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_10um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_10um)):
    sep.append(Si_BSG_d_final_100nm_10um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_10um)
plt.xlim(400,480)
plt.ylim(-1,1)
plt.show()
#From the right: 475

# %%
#SI VS BSG 15UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_1um[0], Si_BSG_d_final_100nm_15um[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_1um[0], Si_BSG_Shifted_Force_100nm_15um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_15um[0], Si_BSG_d_final_100nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_15um)):
    sep.append(Si_BSG_d_final_100nm_15um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_15um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_15um)):
    sep.append(Si_BSG_d_final_100nm_15um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_15um)
plt.xlim(500,700)
plt.ylim(-1,1)
plt.show()
#From the right: 550

# %%
#SI VS BSG 20UM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_20um[0], Si_BSG_d_final_100nm_20um[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_20um[0], Si_BSG_Shifted_Force_100nm_20um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_20um[00], Si_BSG_d_final_100nm_20um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_20um)):
    sep.append(Si_BSG_d_final_100nm_20um[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_20um)
#plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_20um)):
    sep.append(Si_BSG_d_final_100nm_20um[i])
plt.scatter(sep, Si_BSG_Shifted_Force_100nm_20um, s = 0.2)
plt.xlim(350,440)
plt.ylim(-1,7)
plt.show()
#From the right: 380

# %%
#SI VS BSG 500NM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_500nm[0], Si_BSG_d_final_100nm_500nm[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_500nm[0], Si_BSG_Shifted_Force_100nm_500nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_500nm[0], Si_BSG_d_final_100nm_500nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_500nm)):
    sep.append(Si_BSG_d_final_100nm_500nm[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_500nm)):
    sep.append(Si_BSG_d_final_100nm_500nm[i])
plt.scatter(sep, Si_BSG_Shifted_Force_100nm_500nm, s= 0.2)
plt.xlim(40,50)
plt.ylim(-1,1)
plt.show()
#From the right: 46

# %%
#SI VS BSG 800NM
# Define the known points 
x_0 = [Si_BSG_d_final_100nm_800nm[0], Si_BSG_d_final_100nm_800nm[5000]]
y_0 = [Si_BSG_Shifted_Force_100nm_800nm[0], Si_BSG_Shifted_Force_100nm_800nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Si_BSG_d_final_100nm_800nm[8000], Si_BSG_d_final_100nm_800nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_800nm)):
    sep.append(Si_BSG_d_final_100nm_800nm[i])
plt.plot(sep, Si_BSG_Shifted_Force_100nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Si_BSG_d_final_100nm_800nm)):
    sep.append(Si_BSG_d_final_100nm_800nm[i])
plt.scatter(sep, Si_BSG_Shifted_Force_100nm_800nm, s = 0.2)
plt.xlim(60,65)
plt.ylim(-1,1)
plt.show()
#From the right: 64

# %%
#AU VS BSG (X1) 1UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_1um[0], Au_BSG_X1_d_final_1800nm_1um[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_1um[0], Au_BSG_X1_Shifted_Force_1800nm_1um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_1um[0], Au_BSG_X1_d_final_1800nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_1um)):
    sep.append(Au_BSG_X1_d_final_1800nm_1um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_1um)):
    sep.append(Au_BSG_X1_d_final_1800nm_1um[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_1um, s = 0.2)
plt.xlim(65,80)
plt.ylim(-1,1)
plt.show()
#From the right: 75

# %%
#AU VS BSG (X1) 3UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_3um[0], Au_BSG_X1_d_final_1800nm_3um[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_3um[0], Au_BSG_X1_Shifted_Force_1800nm_3um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_3um[0], Au_BSG_X1_d_final_1800nm_3um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_3um)):
    sep.append(Au_BSG_X1_d_final_1800nm_3um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_3um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_3um)):
    sep.append(Au_BSG_X1_d_final_1800nm_3um[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_3um, s = 0.2)
plt.xlim(70,100)
plt.ylim(-1,1)
plt.show()
#From the right: 88

# %%
#AU VS BSG (X1) 7UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_7um[0], Au_BSG_X1_d_final_1800nm_7um[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_7um[0], Au_BSG_X1_Shifted_Force_1800nm_7um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_7um[0], Au_BSG_X1_d_final_1800nm_7um[8000],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_7um)):
    sep.append(Au_BSG_X1_d_final_1800nm_7um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_7um)
#plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_7um)):
    sep.append(Au_BSG_X1_d_final_1800nm_7um[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_7um, s = 0.2)
plt.xlim(120,250)
plt.ylim(-1,1)
plt.show()
#From the right: 180

# %%
#AU VS BSG (X1) 10UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_10um[0], Au_BSG_X1_d_final_1800nm_10um[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_10um[0], Au_BSG_X1_Shifted_Force_1800nm_10um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_10um[0], Au_BSG_X1_d_final_1800nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_10um)):
    sep.append(Au_BSG_X1_d_final_1800nm_10um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_10um)
#plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_10um)):
    sep.append(Au_BSG_X1_d_final_1800nm_10um[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_10um, s = 0.2)
plt.xlim(150,200)
plt.ylim(-1,1)
plt.show()
#From the right: 190

# %%
#AU VS BSG (X1) 15UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_15um[0], Au_BSG_X1_d_final_1800nm_15um[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_15um[0], Au_BSG_X1_Shifted_Force_1800nm_15um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_15um[0], Au_BSG_X1_d_final_1800nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_15um)):
    sep.append(Au_BSG_X1_d_final_1800nm_15um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_15um)
#plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_15um)):
    sep.append(Au_BSG_X1_d_final_1800nm_15um[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_15um, s = 0.2)
plt.xlim(150,200)
plt.ylim(-1,1)
plt.show()
#From the right: 180

# %%
#AU VS BSG (X1) 20UM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_20um[0], Au_BSG_X1_d_final_1800nm_20um[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_20um[0], Au_BSG_X1_Shifted_Force_1800nm_20um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_20um[0], Au_BSG_X1_d_final_1800nm_20um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_20um)):
    sep.append(Au_BSG_X1_d_final_1800nm_20um[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_20um)
#plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_20um)):
    sep.append(Au_BSG_X1_d_final_1800nm_20um[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_20um, s = 0.2)
plt.xlim(150,250)
plt.ylim(-1,1)
plt.show()
#From the right: 190

# %%
#AU VS BSG (X1) 500NM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_500nm[0], Au_BSG_X1_d_final_1800nm_500nm[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_500nm[0], Au_BSG_X1_Shifted_Force_1800nm_500nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_500nm[0], Au_BSG_X1_d_final_1800nm_500nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_500nm[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_500nm[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_500nm, s = 0.2)
plt.xlim(40,60)
plt.ylim(-1,1)
plt.show()
#From the right: 55

# %%
#AU VS BSG (X1) 800NM
# Define the known points 
x_0 = [Au_BSG_X1_d_final_1800nm_800nm[0], Au_BSG_X1_d_final_1800nm_800nm[5000]]
y_0 = [Au_BSG_X1_Shifted_Force_1800nm_800nm[0], Au_BSG_X1_Shifted_Force_1800nm_800nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X1_d_final_1800nm_800nm[0], Au_BSG_X1_d_final_1800nm_800nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_800nm[i])
plt.plot(sep, Au_BSG_X1_Shifted_Force_1800nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X1_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X1_d_final_1800nm_800nm[i])
plt.scatter(sep, Au_BSG_X1_Shifted_Force_1800nm_800nm, s = 0.2)
plt.xlim(60,85)
plt.ylim(-1,1)
plt.show()
#From the right: 76

# %%
#AU VS BSG (X3) 1UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_1um[0], Au_BSG_X3_d_final_1800nm_1um[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_1um[0], Au_BSG_X3_Shifted_Force_1800nm_1um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_1um[0], Au_BSG_X3_d_final_1800nm_1um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_1um)):
    sep.append(Au_BSG_X3_d_final_1800nm_1um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_1um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_1um)):
    sep.append(Au_BSG_X3_d_final_1800nm_1um[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_1um, s = 0.2)
plt.xlim(30,45)
plt.ylim(-1,1)
plt.show()
#From the right: 39

# %%
#AU VS BSG (X3) 3UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_3um[0], Au_BSG_X3_d_final_1800nm_3um[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_3um[0], Au_BSG_X3_Shifted_Force_1800nm_3um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_3um[0], Au_BSG_X3_d_final_1800nm_3um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_3um)):
    sep.append(Au_BSG_X3_d_final_1800nm_3um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_3um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_3um)):
    sep.append(Au_BSG_X3_d_final_1800nm_3um[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_3um, s = 0.2)
plt.xlim(30,45)
plt.ylim(-1,1)
plt.show()
#From the right: 42

# %%
#AU VS BSG (X3) 5UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_5um[0], Au_BSG_X3_d_final_1800nm_5um[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_5um[0], Au_BSG_X3_Shifted_Force_1800nm_5um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_5um[0], Au_BSG_X3_d_final_1800nm_5um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_5um)):
    sep.append(Au_BSG_X3_d_final_1800nm_5um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_5um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_5um)):
    sep.append(Au_BSG_X3_d_final_1800nm_5um[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_5um, s = 0.2)
plt.xlim(45,60)
plt.ylim(-1,1)
plt.show()
#From the right: 51

# %%
#AU VS BSG (X3) 10UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_10um[0], Au_BSG_X3_d_final_1800nm_10um[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_10um[0], Au_BSG_X3_Shifted_Force_1800nm_10um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_10um[0], Au_BSG_X3_d_final_1800nm_10um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_10um)):
    sep.append(Au_BSG_X3_d_final_1800nm_10um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_10um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_10um)):
    sep.append(Au_BSG_X3_d_final_1800nm_10um[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_10um, s = 0.2)
plt.xlim(50,65)
plt.ylim(-1,7)
plt.show()
#From the right: 61

# %%
#AU VS BSG (X3) 15UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_15um[0], Au_BSG_X3_d_final_1800nm_15um[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_15um[0], Au_BSG_X3_Shifted_Force_1800nm_15um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_15um[0], Au_BSG_X3_d_final_1800nm_15um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_15um)):
    sep.append(Au_BSG_X3_d_final_1800nm_15um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_15um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_15um)):
    sep.append(Au_BSG_X3_d_final_1800nm_15um[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_15um, s = 0.2)
plt.xlim(30,100)
plt.ylim(-1,7)
plt.show()
#From the right: 72

# %%
#AU VS BSG (X3) 20UM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_20um[0], Au_BSG_X3_d_final_1800nm_20um[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_20um[0], Au_BSG_X3_Shifted_Force_1800nm_20um[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_20um[0], Au_BSG_X3_d_final_1800nm_20um[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_20um)):
    sep.append(Au_BSG_X3_d_final_1800nm_20um[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_20um)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_20um)):
    sep.append(Au_BSG_X3_d_final_1800nm_20um[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_20um, s = 0.2)
plt.xlim(30,100)
plt.ylim(-1,7)
plt.show()
#From the right: 83

# %%
#AU VS BSG (X3) 500NM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_500nm[0], Au_BSG_X3_d_final_1800nm_500nm[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_500nm[0], Au_BSG_X3_Shifted_Force_1800nm_500nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_500nm[0], Au_BSG_X3_d_final_1800nm_500nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_500nm[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_500nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_500nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_500nm[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_500nm, s = 0.2)
plt.xlim(30,45)
plt.ylim(-1,1)
plt.show()
#From the right: 40

# %%
#AU VS BSG (X3) 800NM
# Define the known points 
x_0 = [Au_BSG_X3_d_final_1800nm_800nm[0], Au_BSG_X3_d_final_1800nm_800nm[5000]]
y_0 = [Au_BSG_X3_Shifted_Force_1800nm_800nm[0], Au_BSG_X3_Shifted_Force_1800nm_800nm[5000]]

x = []
y = []
for i in x_0:
    x.append(i[0])
for i in y_0:
    y.append(i[0])

# Calculate the coefficients. This line answers the initial question. 
coefficients = np.polyfit(x, y, 1)

# Print the findings
print('a =', coefficients[0])
print('b =', coefficients[1])

# Let's compute the values of the line...
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(Au_BSG_X3_d_final_1800nm_800nm[0], Au_BSG_X3_d_final_1800nm_800nm[8700],100)
y_axis = polynomial(x_axis)

#lot the points and the line
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_800nm[i])
plt.plot(sep, Au_BSG_X3_Shifted_Force_1800nm_800nm)
plt.xlim(-20,150)
plt.ylim(-1,7)
plt.show()
plt.plot(x_axis, y_axis)
plt.plot( x[0], y[0], 'go' )
plt.plot( x[1], y[1], 'go' )
sep = []
for i in range(len(Au_BSG_X3_d_final_1800nm_800nm)):
    sep.append(Au_BSG_X3_d_final_1800nm_800nm[i])
plt.scatter(sep, Au_BSG_X3_Shifted_Force_1800nm_800nm, s = 0.2)
plt.xlim(30,45)
plt.ylim(-1,1)
plt.show()
#From the right: 38

# %% [markdown]
# ### Plot JUST non-linear part

# %%
#Slip length CHINESE PAPER approach FOR 500NMS
v = 500*10**-9      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 32.0
bb_Au_Au = 38.0
aa_Si_BSG = 31.0
bb_Si_BSG = 37.0
aa_Au_BSG_X1 = 51.0
bb_Au_BSG_X1 = 55.0
aa_Au_BSG_X3 = 33.5
bb_Au_BSG_X3 = 38.0
aa_Au_BSG = 38.0
bb_Au_BSG = 46.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_500nm)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_500nm[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_500nm)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_500nm[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_500nm)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_500nm[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_500nm)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_500nm[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[0])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[0][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)              #We convert force to N
        vF.append(x)
    return vF

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i]*10**-9)                 #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_500nm,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_500nm,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_500nm,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_500nm,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_500nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_500nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_500nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_500nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[0],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[0],min_range_Au_BSG,max_range_Au_BSG))]

#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_500nms = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_500nms = model_Au_Au.intercept_
slope_Au_Au_500nms = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_500nms = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_500nms = model_Si_BSG.intercept_
slope_Si_BSG_500nms = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_500nms = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_500nms = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_500nms = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_500nms = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_500nms = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_500nms = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#AU vs BSG 
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_500nms = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_500nms = model_Au_BSG.intercept_
slope_Au_BSG_500nms = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title(r'$0.5 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1],color='royalblue', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], color='red', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], color='darkorange', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au,color='royalblue', label=f'Au vs Au, b={30.45}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b={27.76}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_500nms}')

#plt.plot(args_Au_BSG_X1[0], r_sq_Au_BSG_X1_500nms*y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_500nms}')
#plt.plot(args_Au_BSG_X1[0], (1/r_sq_Au_BSG_X1_500nms)*y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_500nms}')


#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_500nms}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG,color='darkorange', label=f'Au vs BSG, b={32.0}')
plt.xlabel("Separation distance(nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='12')
plt.xlim(30, 48)
plt.ylim(300, 5000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_500nms}")
print(f"The intercept is of: {intercept_Au_Au_500nms}")   
print(f"The determination coefficient is of: {r_sq_Au_Au_500nms}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_500nms}")
print(f"The intercept is of: {intercept_Si_BSG_500nms}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_500nms}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_500nms}")
print(f"The intercept is of: {intercept_Au_BSG_X1_500nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_500nms}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_500nms}")
print(f"The intercept is of: {intercept_Au_BSG_X3_500nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_500nms}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_500nms}")
print(f"The intercept is of: {intercept_Au_BSG_500nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_500nms}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2304237192.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_500nm[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2304237192.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2304237192.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 500NMS
v = 500*10**-9      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 32.0
bb_Au_Au = 39.0
aa_Si_BSG = 31.0
bb_Si_BSG = 37.0
aa_Au_BSG_X1 = 51.0
bb_Au_BSG_X1 = 55.0
aa_Au_BSG_X3 = 33.5
bb_Au_BSG_X3 = 38.0
aa_Au_BSG = 38.0
bb_Au_BSG = 46.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_500nm)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_500nm[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_500nm)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_500nm[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_500nm)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_500nm[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_500nm)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_500nm[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[0])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[0][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0]*10**-9)/v              #We convert force to N
        vF.append(x)
    return vF

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i]*10**-9)/v                 #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_500nm,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_500nm,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_500nm,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_500nm,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_500nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_500nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_500nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_500nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[0],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[0],min_range_Au_BSG,max_range_Au_BSG))]

#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_500nms = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_500nms = model_Au_Au.intercept_
slope_Au_Au_500nms = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_500nms = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_500nms = model_Si_BSG.intercept_
slope_Si_BSG_500nms = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_500nms = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_500nms = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_500nms = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_500nms = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_500nms = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_500nms = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#AU vs BSG 
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_500nms = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_500nms = model_Au_BSG.intercept_
slope_Au_BSG_500nms = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title("500nm/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], label='Au vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_500nms}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG_500nms}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_500nms}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_500nms}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, label=f'slip length: {intercept_Au_BSG_500nms}')
plt.xlabel("1/Separation (nm)")
plt.ylabel("Velocity/Force (ms/N)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_500nms}")
print(f"The intercept is of: {intercept_Au_Au_500nms*10**-9*6*math.pi*r**2*n}")    #as intercept = b/(constant) = b/(6*math.pi*r**2*n)
print(f"The determination coefficient is of: {r_sq_Au_Au_500nms}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_500nms}")
print(f"The intercept is of: {intercept_Si_BSG_500nms}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_500nms}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_500nms}")
print(f"The intercept is of: {intercept_Au_BSG_X1_500nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_500nms}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_500nms}")
print(f"The intercept is of: {intercept_Au_BSG_X3_500nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_500nms}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_500nms}")
print(f"The intercept is of: {intercept_Au_BSG_500nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_500nms}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_29072\3829958722.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_500nm[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_29072\3829958722.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_29072\3829958722.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 800NMS
v = 800*10**-9      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 24.0
bb_Au_Au = 30.0
aa_Si_BSG = 28.5
bb_Si_BSG = 40.0
aa_Au_BSG_X1 = 50.0
bb_Au_BSG_X1 = 76.0
aa_Au_BSG_X3 = 33.0
bb_Au_BSG_X3 = 38.0
aa_Au_BSG = 43.0
bb_Au_BSG = 55.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_800nm)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_800nm[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_800nm)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_800nm[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_800nm)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_800nm[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_800nm)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_800nm[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[1])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[1][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i]*10**-9)
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_800nm,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_800nm,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_800nm,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_800nm,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_800nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_800nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_800nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_800nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[1],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[1],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_800nms = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_800nms = model_Au_Au.intercept_
slope_Au_Au_800nms = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_800nms = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_800nms = model_Si_BSG.intercept_
slope_Si_BSG_800nms = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_800nms = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_800nms = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_800nms = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_800nms = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_800nms = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_800nms = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_800nms = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_800nms = model_Au_BSG.intercept_
slope_Au_BSG_800nms = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title(r'$0.8 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1],color='royalblue', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1],color='red', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1],color='darkorange', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au,color='royalblue', label=f'Au vs Au, b={24.35}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b={26.8}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_800nms}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_800nms}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG,color='darkorange', label=f'Au vs BSG, b={43.24}')
plt.xlabel("Separation distance(nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='12')
plt.xlim(20, 60)
plt.ylim(-200, 14000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_800nms}")
print(f"The intercept is of: {intercept_Au_Au_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_Au_800nms}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_800nms}")
print(f"The intercept is of: {intercept_Si_BSG_800nms}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_800nms}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_800nms}")
print(f"The intercept is of: {intercept_Au_BSG_X1_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_800nms}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_800nms}")
print(f"The intercept is of: {intercept_Au_BSG_X3_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_800nms}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_800nms}")
print(f"The intercept is of: {intercept_Au_BSG_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_800nms}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\663239030.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_800nm[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\663239030.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\663239030.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 800NMS
v = 0.8
#From 7.5 to 11
aa_Au_Au = 24.0
bb_Au_Au = 30.0
aa_Si_BSG = 28.5
bb_Si_BSG = 40.0
aa_Au_BSG_X1 = 50.0
bb_Au_BSG_X1 = 76.0
aa_Au_BSG_X3 = 33.0
bb_Au_BSG_X3 = 38.0
aa_Au_BSG = 43.0
bb_Au_BSG = 55.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_800nm)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_800nm[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_800nm)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_800nm[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_800nm)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_800nm[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_800nm)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_800nm[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[1])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[1][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i])/v
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_800nm,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_800nm,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_800nm,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_800nm,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_800nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_800nm,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_800nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_800nm,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[1],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[1],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_800nms = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_800nms = model_Au_Au.intercept_
slope_Au_Au_800nms = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_800nms = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_800nms = model_Si_BSG.intercept_
slope_Si_BSG_800nms = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_800nms = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_800nms = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_800nms = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_800nms = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_800nms = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_800nms = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_800nms = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_800nms = model_Au_BSG.intercept_
slope_Au_BSG_800nms = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title("800nm/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], label='Au vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_800nms}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG_800nms}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_800nms}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_800nms}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, label=f'slip length: {intercept_Au_BSG_800nms}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_800nms}")
print(f"The intercept is of: {intercept_Au_Au_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_Au_800nms}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_800nms}")
print(f"The intercept is of: {intercept_Si_BSG_800nms}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_800nms}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_800nms}")
print(f"The intercept is of: {intercept_Au_BSG_X1_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_800nms}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_800nms}")
print(f"The intercept is of: {intercept_Au_BSG_X3_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_800nms}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_800nms}")
print(f"The intercept is of: {intercept_Au_BSG_800nms}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_800nms}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\4058157972.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_800nm[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\4058157972.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\4058157972.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 1UMS
v = 1.0*10**-6      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 26.0
bb_Au_Au = 32.0
aa_Si_BSG = 28.5
bb_Si_BSG = 42.0
aa_Au_BSG_X1 = 48.0
bb_Au_BSG_X1 = 60.0
aa_Au_BSG_X3 = 35.0
bb_Au_BSG_X3 = 39.0
aa_Au_BSG = 42.0
bb_Au_BSG = 50.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_1um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_1um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_1um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_1um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_1um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_1um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_1um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_1um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[2])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[2][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)                     #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i]*10**-9)                        #We convert force to N
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_1um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_1um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_1um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_1um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_1um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_1um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_1um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_1um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[2],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[2],min_range_Au_BSG,max_range_Au_BSG))]

#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_1ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_1ums = model_Au_Au.intercept_
slope_Au_Au_1ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_1ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_1ums = model_Si_BSG.intercept_
slope_Si_BSG_1ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_1ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_1ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_1ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_1ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_1ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_1ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_1ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_1ums = model_Au_BSG.intercept_
slope_Au_BSG_1ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title(r'$1\mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1],color='royalblue', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1],color='red', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1],color='darkorange', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, color='royalblue',label=f'Au vs Au, b= {24.58}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b= {27.22}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_1ums}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_1ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, color='darkorange',label=f'Au vs BSG, b= {39.25}')
plt.xlabel("Separation distance (nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='12')
plt.xlim(25, 51)
plt.ylim(-100, 9000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_1ums}")
print(f"The intercept is of: {intercept_Au_Au_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_1ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_1ums}")
print(f"The intercept is of: {intercept_Si_BSG_1ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_1ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_1ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_1ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_1ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_1ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_1ums}")
print(f"The intercept is of: {intercept_Au_BSG_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_1ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2549285412.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_1um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2549285412.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2549285412.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 1UMS
v = 1.0
#From 7.5 to 11
aa_Au_Au = 26.0
bb_Au_Au = 32.0
aa_Si_BSG = 28.5
bb_Si_BSG = 42.0
aa_Au_BSG_X1 = 48.0
bb_Au_BSG_X1 = 60.0
aa_Au_BSG_X3 = 35.0
bb_Au_BSG_X3 = 39.0
aa_Au_BSG = 42.0
bb_Au_BSG = 50.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_1um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_1um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_1um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_1um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_1um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_1um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_1um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_1um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[2])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[2][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i])/v
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_1um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_1um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_1um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_1um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_1um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_1um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_1um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_1um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[2],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[2],min_range_Au_BSG,max_range_Au_BSG))]

#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_1ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_1ums = model_Au_Au.intercept_
slope_Au_Au_1ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_1ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_1ums = model_Si_BSG.intercept_
slope_Si_BSG_1ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_1ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_1ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_1ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_1ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_1ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_1ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_1ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_1ums = model_Au_BSG.intercept_
slope_Au_BSG_1ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title("1um/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'Au vs Au, b= {intercept_Au_Au_1ums}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'Si vs BSG, b= {intercept_Si_BSG_1ums}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_1ums}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_1ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, label=f'Au vs BSG, b= {intercept_Au_BSG_1ums}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_1ums}")
print(f"The intercept is of: {intercept_Au_Au_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_1ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_1ums}")
print(f"The intercept is of: {intercept_Si_BSG_1ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_1ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_1ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_1ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_1ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_1ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_1ums}")
print(f"The intercept is of: {intercept_Au_BSG_1ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_1ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_27444\198412960.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_1um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_27444\198412960.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_27444\198412960.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 3UMS
v = 3.0*10**-6      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 26.5
bb_Au_Au = 35.0
aa_Au_BSG_X1 = 31.5
bb_Au_BSG_X1 = 88.0
aa_Au_BSG_X3 = 31.0
bb_Au_BSG_X3 = 42.0
aa_Au_BSG = 28.0
bb_Au_BSG = 45.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_3um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_3um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_3um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_3um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_3um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_3um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[3])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[3][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)              #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i]*10**-9)                 #We convert force to N
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_3um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_3um,min_range_Au_Au,max_range_Au_Au))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_3um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_3um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_3um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_3um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[3],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[3],min_range_Au_BSG,max_range_Au_BSG))]

#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_3ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_3ums = model_Au_Au.intercept_
slope_Au_Au_3ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_3ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_3ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_3ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_3ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_3ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_3ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_3ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_3ums = model_Au_BSG.intercept_
slope_Au_BSG_3ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title(r'$3 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1],color='royalblue', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1],color='darkorange', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au,color='royalblue', label=f'Au vs Au, b={23.77}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_3ums}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_3ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG,color='darkorange', label=f'Au vs BSG, b={27.6}')
plt.xlabel("Separation distance(nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='12')
plt.xlim(25, 48)
plt.ylim(0, 10000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_3ums}")
print(f"The intercept is of: {intercept_Au_Au_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_3ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_3ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_3ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_3ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_3ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_3ums}")
print(f"The intercept is of: {intercept_Au_BSG_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_3ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2142516502.py:21: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_3um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2142516502.py:22: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2142516502.py:32: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 3UMS
v = 3.0
#From 7.5 to 11
aa_Au_Au = 20.5
bb_Au_Au = 40.0
aa_Au_BSG_X1 = 31.5
bb_Au_BSG_X1 = 88.0
aa_Au_BSG_X3 = 31.0
bb_Au_BSG_X3 = 42.0
aa_Au_BSG = 25.0
bb_Au_BSG = 50.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_3um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_3um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_3um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_3um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_3um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_3um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[3])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[3][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i])/v
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_3um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_3um,min_range_Au_Au,max_range_Au_Au))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_3um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_3um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_3um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_3um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[3],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[3],min_range_Au_BSG,max_range_Au_BSG))]

#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_3ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_3ums = model_Au_Au.intercept_
slope_Au_Au_3ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_3ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_3ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_3ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_3ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_3ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_3ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_3ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_3ums = model_Au_BSG.intercept_
slope_Au_BSG_3ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title("3um/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], label='Au vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_3ums}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_3ums}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_3ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, label=f'slip length: {intercept_Au_BSG_3ums}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_3ums}")
print(f"The intercept is of: {intercept_Au_Au_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_3ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_3ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_3ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_3ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_3ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_3ums}")
print(f"The intercept is of: {intercept_Au_BSG_3ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_3ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\436623561.py:21: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_3um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\436623561.py:22: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\436623561.py:32: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 5UMS
v = 5.0*10**-6
#From 7.5 to 11
aa_Au_Au = 22.5
bb_Au_Au = 33.0
aa_Si_BSG = 22.5
bb_Si_BSG = 40.0
aa_Au_BSG_X3 = 25.0
bb_Au_BSG_X3 = 51.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_5um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_5um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_5um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_5um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_5um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_5um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)              #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_5um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_5um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_5um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_5um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_5um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_5um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_5ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_5ums = model_Au_Au.intercept_
slope_Au_Au_5ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_5ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_5ums = model_Si_BSG.intercept_
slope_Si_BSG_5ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_5ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_5ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_5ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])


#Plotting
plt.title(r'$5 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1],color='royalblue',  s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1],color='red', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, color='royalblue', label=f'Au vs Au, b={22.14}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b={29.8}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_5ums}')
plt.xlabel("Separation distance (nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='13')
plt.xlim(20, 42)
plt.ylim(-1000, 25000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_5ums}")
print(f"The intercept is of: {intercept_Au_Au_5ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_5ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_5ums}")
print(f"The intercept is of: {intercept_Si_BSG_5ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_5ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_5ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_5ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_5ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\1671844798.py:19: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_5um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\1671844798.py:20: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\1671844798.py:30: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 5UMS
v = 5.0
#From 7.5 to 11
aa_Au_Au = 19.5
bb_Au_Au = 43.0
aa_Si_BSG = 22.5
bb_Si_BSG = 225.0
aa_Au_BSG_X3 = 25.0
bb_Au_BSG_X3 = 51.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_5um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_5um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_5um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_5um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_5um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_5um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_5um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_5um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_5um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_5um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_5um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_5um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_5ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_5ums = model_Au_Au.intercept_
slope_Au_Au_5ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_5ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_5ums = model_Si_BSG.intercept_
slope_Si_BSG_5ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_5ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_5ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_5ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])


#Plotting
plt.title("5um/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_5ums}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG_5ums}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_5ums}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_5ums}")
print(f"The intercept is of: {intercept_Au_Au_5ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_5ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_5ums}")
print(f"The intercept is of: {intercept_Si_BSG_5ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_5ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_5ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_5ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_5ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\2295280138.py:19: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_5um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\2295280138.py:20: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\2295280138.py:30: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 7UMS
v = 7.0*10**-6      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 20.0
bb_Au_Au = 28.0
aa_Si_BSG = 21.5
bb_Si_BSG = 45.0
aa_Au_BSG_X1 = 43.0
bb_Au_BSG_X1 = 70.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_7um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_7um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_7um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_7um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_7um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_7um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)                     #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_7um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_7um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_7um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_7um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_7um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_7um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_7ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_7ums = model_Au_Au.intercept_
slope_Au_Au_7ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_7ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_7ums = model_Si_BSG.intercept_
slope_Si_BSG_7ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_7ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_7ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_7ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])


#Plotting
plt.title(r'$7 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1],color='royalblue', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1],color='red', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au,color='royalblue', label=f'Au vs Au, b={22.1}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b={39.5}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_7ums}')
plt.xlabel("Separation distance (nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='13')
plt.xlim(17, 47)
plt.ylim(1000, 16000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_7ums}")
print(f"The intercept is of: {intercept_Au_Au_7ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_7ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_7ums}")
print(f"The intercept is of: {intercept_Si_BSG_7ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_7ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_7ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_7ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_7ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\1865934473.py:19: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_7um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\1865934473.py:20: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\1865934473.py:30: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 7UMS
v = 7.0
#From 7.5 to 11
aa_Au_Au = 19.0
bb_Au_Au = 38.0
aa_Si_BSG = 21.5
bb_Si_BSG = 300.0
aa_Au_BSG_X1 = 43.0
bb_Au_BSG_X1 = 70.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_7um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_7um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_7um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_7um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_7um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_7um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_7um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_7um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_7um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_7um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_7um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_7um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_7ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_7ums = model_Au_Au.intercept_
slope_Au_Au_7ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_7ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_7ums = model_Si_BSG.intercept_
slope_Si_BSG_7ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_7ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_7ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_7ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])


#Plotting
plt.title("7um/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_7ums}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG_7ums}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_7ums}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_7ums}")
print(f"The intercept is of: {intercept_Au_Au_7ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_7ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_7ums}")
print(f"The intercept is of: {intercept_Si_BSG_7ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_7ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_7ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_7ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_7ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\1863080507.py:19: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_7um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\1863080507.py:20: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\1863080507.py:30: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 10UMS
v = 10.0*10**-6      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 7.5
bb_Au_Au = 11.0
aa_Si_BSG = 20.0
bb_Si_BSG = 35.0
aa_Au_BSG_X1 = 41.5
bb_Au_BSG_X1 = 55.0
aa_Au_BSG_X3 = 25.0
bb_Au_BSG_X3 = 61.0
aa_Au_BSG = 33.0
bb_Au_BSG = 45.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_10um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_10um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_10um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_10um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_10um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_10um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_10um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_10um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[4])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[4][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)                     #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i]*10**-9)                     #We convert force to N
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_10um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_10um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_10um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_10um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_10um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_10um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_10um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_10um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[4],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[4],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_10ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_10ums = model_Au_Au.intercept_
slope_Au_Au_10ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_10ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_10ums = model_Si_BSG.intercept_
slope_Si_BSG_10ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_10ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_10ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_10ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_10ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_10ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_10ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_10ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_10ums = model_Au_BSG.intercept_
slope_Au_BSG_10ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title(r'$10 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1],color='royalblue',  s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], color='red',s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1],color='darkorange', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au,color='royalblue',  label=f'Au vs Au, b={6.695}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b={49.2}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_10ums}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_10ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG,color='darkorange', label=f'Au vs BSG, b={36.5}')
plt.xlabel("Separation distance (nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='12')
#plt.xlim(-2, 255)
#plt.ylim(-20000, 47500)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_10ums}")
print(f"The intercept is of: {intercept_Au_Au_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_10ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_10ums}")
print(f"The intercept is of: {intercept_Si_BSG_10ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_10ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_10ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_10ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_10ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_10ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_10ums}")
print(f"The intercept is of: {intercept_Au_BSG_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_10ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\3067389378.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_10um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\3067389378.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\3067389378.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 10UMS
v = 10.0
#From 7.5 to 11
aa_Au_Au = 7.5
bb_Au_Au = 11.0
aa_Si_BSG = 20.0
bb_Si_BSG = 475.0
aa_Au_BSG_X1 = 41.5
bb_Au_BSG_X1 = 190.0
aa_Au_BSG_X3 = 25.0
bb_Au_BSG_X3 = 61.0
aa_Au_BSG = 32.0
bb_Au_BSG = 61.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_10um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_10um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_10um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_10um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_10um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_10um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_10um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_10um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[4])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[4][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i])/v
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_10um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_10um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_10um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_10um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_10um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_10um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_10um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_10um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[4],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[4],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_10ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_10ums = model_Au_Au.intercept_
slope_Au_Au_10ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_10ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_10ums = model_Si_BSG.intercept_
slope_Si_BSG_10ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_10ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_10ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_10ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_10ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_10ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_10ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_10ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_10ums = model_Au_BSG.intercept_
slope_Au_BSG_10ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title("10um/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], label='Au vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_10ums}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG_10ums}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_10ums}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_10ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, label=f'slip length: {intercept_Au_BSG_10ums}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_10ums}")
print(f"The intercept is of: {intercept_Au_Au_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_10ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_10ums}")
print(f"The intercept is of: {intercept_Si_BSG_10ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_10ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_10ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_10ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_10ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_10ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_10ums}")
print(f"The intercept is of: {intercept_Au_BSG_10ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_10ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\1923742183.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_10um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\1923742183.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\1923742183.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 15UMS
v = 15.0*10**-6      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 2.0
bb_Au_Au = 6.0
aa_Si_BSG = 18.5
bb_Si_BSG = 50.0
aa_Au_BSG_X1 = 49.0
bb_Au_BSG_X1 = 180.0
aa_Au_BSG_X3 = 34.0
bb_Au_BSG_X3 = 72.0
aa_Au_BSG = 42.0
bb_Au_BSG = 52.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_15um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_15um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_15um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_15um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_15um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_15um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_15um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_15um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[5])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[5][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)                     #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i]*10**-9)                     #We convert force to N
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_15um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_15um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_15um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_15um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_15um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_15um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_15um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_15um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[5],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[5],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_15ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_15ums = model_Au_Au.intercept_
slope_Au_Au_15ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_15ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_15ums = model_Si_BSG.intercept_
slope_Si_BSG_15ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_15ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_15ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_15ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_15ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_15ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_15ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_15ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_15ums = model_Au_BSG.intercept_
slope_Au_BSG_15ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title(r'$15 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1], color='royalblue',s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1],color='red', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], color='darkorange',s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au,color='royalblue', label=f'Au vs Au, b={16.4}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b={62.5}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_15ums}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_15ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, color='darkorange',label=f'Au vs BSG, b={38.2}')
plt.xlabel("Separation distance (nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='12')
#plt.xlim(-2, 255)
#plt.ylim(-20000, 67500)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_15ums}")
print(f"The intercept is of: {intercept_Au_Au_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_15ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_15ums}")
print(f"The intercept is of: {intercept_Si_BSG_15ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_15ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_15ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_15ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_15ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_15ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_15ums}")
print(f"The intercept is of: {intercept_Au_BSG_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_15ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2441147900.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_15um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2441147900.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2441147900.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 15UMS
v = 15.0
#From 7.5 to 11
aa_Au_Au = 8.0
bb_Au_Au = 130.0
aa_Si_BSG = 18.5
bb_Si_BSG = 550.0
aa_Au_BSG_X1 = 49.0
bb_Au_BSG_X1 = 180.0
aa_Au_BSG_X3 = 34.0
bb_Au_BSG_X3 = 72.0
aa_Au_BSG = 40.0
bb_Au_BSG = 72.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_15um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_15um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_15um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_15um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_15um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_15um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_15um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_15um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[5])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[5][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i])/v
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_15um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_15um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_15um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_15um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_15um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_15um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_15um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_15um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[5],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[5],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_15ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_15ums = model_Au_Au.intercept_
slope_Au_Au_15ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_15ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_15ums = model_Si_BSG.intercept_
slope_Si_BSG_15ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_15ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_15ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_15ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_15ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_15ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_15ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_15ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_15ums = model_Au_BSG.intercept_
slope_Au_BSG_15ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])


#Plotting
plt.title("15um/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], label='Au vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_15ums}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG_15ums}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_15ums}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_15ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, label=f'slip length: {intercept_Au_BSG_15ums}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_15ums}")
print(f"The intercept is of: {intercept_Au_Au_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_15ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_15ums}")
print(f"The intercept is of: {intercept_Si_BSG_15ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_15ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_15ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_15ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_15ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_15ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_15ums}")
print(f"The intercept is of: {intercept_Au_BSG_15ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_15ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\3142933545.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_15um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\3142933545.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\3142933545.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#Slip length CHINES PAPER approach FOR 20UMS
v = 20.0*10**-6      #velocity in meters
#From 7.5 to 11
aa_Au_Au = 12.0
bb_Au_Au = 22.0
aa_Si_BSG = 20.0
bb_Si_BSG = 100.0
aa_Au_BSG_X1 = 49.0
bb_Au_BSG_X1 = 190.0
aa_Au_BSG_X3 = 32.0
bb_Au_BSG_X3 = 83.0
aa_Au_BSG = 40.0
bb_Au_BSG = 55.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_20um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_20um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_20um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_20um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_20um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_20um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_20um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_20um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)


min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[6])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[6][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i][0]*10**-9)                        #We convert force to N
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = v/(F[i]*10**-9)                        #We convert force to N
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = (d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_20um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_20um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_20um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_20um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_20um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_20um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_20um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_20um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[6],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[6],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_20ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_20ums = model_Au_Au.intercept_
slope_Au_Au_20ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_20ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_20ums = model_Si_BSG.intercept_
slope_Si_BSG_20ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_20ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_20ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_20ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_20ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_20ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_20ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG X
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_20ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_20ums = model_Au_BSG.intercept_
slope_Au_BSG_20ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])

#Plotting
plt.title(r'$20 \mu m/s$ slip lengths', fontsize='17')
plt.scatter(args_Au_Au[0],args_Au_Au[1], color='royalblue', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], color='red', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
#plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], color='darkorange', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au,color='royalblue', label=f'Au vs Au, b={40.4}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG,color='red', label=f'Si vs BSG, b={38.91}')
#plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_20ums}')
#plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_20ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, color='darkorange',label=f'Au vs BSG, b={33.38}')
plt.xlabel("Separation distance (nm)", fontsize='14')
plt.ylabel("Velocity/Force (ms/N)", fontsize='14')
plt.legend(fontsize='12')
#plt.xlim(-2, 255)
#plt.ylim(-20000, 127500)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_20ums}")
print(f"The intercept is of: {intercept_Au_Au_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_20ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_20ums}")
print(f"The intercept is of: {intercept_Si_BSG_20ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_20ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_20ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_20ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_20ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_20ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_20ums}")
print(f"The intercept is of: {intercept_Au_BSG_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_20ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2762996368.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_20um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2762996368.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_35248\2762996368.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %%
#V/F against 1/d to fit the function from theory FOR 20UMS
v = 20.0
#From 7.5 to 11
aa_Au_Au = 28.0
bb_Au_Au = 400.0
aa_Si_BSG = 20.0
bb_Si_BSG = 380.0
aa_Au_BSG_X1 = 49.0
bb_Au_BSG_X1 = 190.0
aa_Au_BSG_X3 = 32.0
bb_Au_BSG_X3 = 83.0
aa_Au_BSG = 40.0
bb_Au_BSG = 83.0

import numpy as np
from sklearn.linear_model import LinearRegression

#Search for positions
k_Au_Au = 0
k_stored_Au_Au = []
for i in range(len(Au_Au_d_final_1800nm_20um)):
    k_Au_Au = k_Au_Au+1
    a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_20um[i][0] < bb_Au_Au)
    if a_Au_Au[0] == 0:
        k_stored_Au_Au.append(k_Au_Au)

min_range_Au_Au = min(k_stored_Au_Au)
max_range_Au_Au = max(k_stored_Au_Au)

k_Si_BSG = 0
k_stored_Si_BSG = []
for i in range(len(Si_BSG_d_final_100nm_20um)):
    k_Si_BSG = k_Si_BSG+1
    a_Si_BSG = np.where(aa_Si_BSG < Si_BSG_d_final_100nm_20um[i][0] < bb_Si_BSG)
    if a_Si_BSG[0] == 0:
        k_stored_Si_BSG.append(k_Si_BSG)

min_range_Si_BSG = min(k_stored_Si_BSG)
max_range_Si_BSG = max(k_stored_Si_BSG)

k_Au_BSG_X1 = 0
k_stored_Au_BSG_X1 = []
for i in range(len(Au_BSG_X1_d_final_1800nm_20um)):
    k_Au_BSG_X1 = k_Au_BSG_X1+1
    a_Au_BSG_X1 = np.where(aa_Au_BSG_X1 < Au_BSG_X1_d_final_1800nm_20um[i][0] < bb_Au_BSG_X1)
    if a_Au_BSG_X1[0] == 0:
        k_stored_Au_BSG_X1.append(k_Au_BSG_X1)

min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG_X3 = 0
k_stored_Au_BSG_X3 = []
for i in range(len(Au_BSG_X3_d_final_1800nm_20um)):
    k_Au_BSG_X3 = k_Au_BSG_X3+1
    a_Au_BSG_X3 = np.where(aa_Au_BSG_X3 < Au_BSG_X3_d_final_1800nm_20um[i][0] < bb_Au_BSG_X3)
    if a_Au_BSG_X3[0] == 0:
        k_stored_Au_BSG_X3.append(k_Au_BSG_X3)

min_range_Au_BSG_X3 = min(k_stored_Au_BSG_X3)
max_range_Au_BSG_X3 = max(k_stored_Au_BSG_X3)


min_range_Au_BSG_X1 = min(k_stored_Au_BSG_X1)
max_range_Au_BSG_X1 = max(k_stored_Au_BSG_X1)

k_Au_BSG = 0
k_stored_Au_BSG = []
for i in range(len(X1X3_distance[6])):
    k_Au_BSG = k_Au_BSG+1
    a_Au_BSG = np.where(aa_Au_BSG < X1X3_distance[6][i] < bb_Au_BSG)
    if a_Au_BSG[0] == 0:
        k_stored_Au_BSG.append(k_Au_BSG)

min_range_Au_BSG = min(k_stored_Au_BSG)
max_range_Au_BSG = max(k_stored_Au_BSG)

#Functions
def slip_length(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i][0])/v
        vF.append(x)
    return vF

def inverse_distance(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i][0])
        d_inverse.append(x)
    return d_inverse

def slip_length_diff(v,F,min_range,max_range):
    vF = []
    for i in range(min_range,max_range):       
        x = (F[i])/v
        vF.append(x)
    return vF

def inverse_distance_diff(d,min_range,max_range):
    d_inverse = []
    for i in range(min_range,max_range):       
        x = 1.0/(d[i])
        d_inverse.append(x)
    return d_inverse

#Arguemnts for plotting
args_Au_Au = [np.array(inverse_distance(Au_Au_d_final_1800nm_20um,min_range_Au_Au,max_range_Au_Au)).reshape((-1,1)), np.array(slip_length(v,Au_Au_Shifted_Force_1800nm_20um,min_range_Au_Au,max_range_Au_Au))]
args_Si_BSG = [np.array(inverse_distance(Si_BSG_d_final_100nm_20um,min_range_Si_BSG,max_range_Si_BSG)).reshape((-1,1)), np.array(slip_length(v,Si_BSG_Shifted_Force_100nm_20um,min_range_Si_BSG,max_range_Si_BSG))]
args_Au_BSG_X1 = [np.array(inverse_distance(Au_BSG_X1_d_final_1800nm_20um,min_range_Au_BSG_X1,max_range_Au_BSG_X1)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X1_Shifted_Force_1800nm_20um,min_range_Au_BSG_X1,max_range_Au_BSG_X1))]
args_Au_BSG_X3 = [np.array(inverse_distance(Au_BSG_X3_d_final_1800nm_20um,min_range_Au_BSG_X3,max_range_Au_BSG_X3)).reshape((-1,1)), np.array(slip_length(v,Au_BSG_X3_Shifted_Force_1800nm_20um,min_range_Au_BSG_X3,max_range_Au_BSG_X3))]
args_Au_BSG = [np.array(inverse_distance_diff(X1X3_distance[6],min_range_Au_BSG,max_range_Au_BSG)).reshape((-1,1)), np.array(slip_length_diff(v,X1X3_force[6],min_range_Au_BSG,max_range_Au_BSG))]


#Au vs Au
model_Au_Au = LinearRegression().fit(args_Au_Au[0],args_Au_Au[1])
r_sq_Au_Au_20ums = model_Au_Au.score(args_Au_Au[0],args_Au_Au[1])
intercept_Au_Au_20ums = model_Au_Au.intercept_
slope_Au_Au_20ums = model_Au_Au.coef_
y_pred_Au_Au = model_Au_Au.predict(args_Au_Au[0])
#Si vs BSG
model_Si_BSG = LinearRegression().fit(args_Si_BSG[0],args_Si_BSG[1])
r_sq_Si_BSG_20ums = model_Si_BSG.score(args_Si_BSG[0],args_Si_BSG[1])
intercept_Si_BSG_20ums = model_Si_BSG.intercept_
slope_Si_BSG_20ums = model_Si_BSG.coef_
y_pred_Si_BSG = model_Si_BSG.predict(args_Si_BSG[0])
#Au vs BSG X1
model_Au_BSG_X1 = LinearRegression().fit(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
r_sq_Au_BSG_X1_20ums = model_Au_BSG_X1.score(args_Au_BSG_X1[0],args_Au_BSG_X1[1])
intercept_Au_BSG_X1_20ums = model_Au_BSG_X1.intercept_
slope_Au_BSG_X1_20ums = model_Au_BSG_X1.coef_
y_pred_Au_BSG_X1 = model_Au_BSG_X1.predict(args_Au_BSG_X1[0])
#Au vs BSG X3
model_Au_BSG_X3 = LinearRegression().fit(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
r_sq_Au_BSG_X3_20ums = model_Au_BSG_X3.score(args_Au_BSG_X3[0],args_Au_BSG_X3[1])
intercept_Au_BSG_X3_20ums = model_Au_BSG_X3.intercept_
slope_Au_BSG_X3_20ums = model_Au_BSG_X3.coef_
y_pred_Au_BSG_X3 = model_Au_BSG_X3.predict(args_Au_BSG_X3[0])
#Au vs BSG X
model_Au_BSG = LinearRegression().fit(args_Au_BSG[0],args_Au_BSG[1])
r_sq_Au_BSG_20ums = model_Au_BSG.score(args_Au_BSG[0],args_Au_BSG[1])
intercept_Au_BSG_20ums = model_Au_BSG.intercept_
slope_Au_BSG_20ums = model_Au_BSG.coef_
y_pred_Au_BSG = model_Au_BSG.predict(args_Au_BSG[0])

#Plotting
plt.title("20um/s slip lengths")
plt.scatter(args_Au_Au[0],args_Au_Au[1], label='Au vs Au', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Si_BSG[0],args_Si_BSG[1], label='Si vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X1[0],args_Au_BSG_X1[1], label='Au vs BSG X1', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG_X3[0],args_Au_BSG_X3[1], label='Au vs BSG X3', s=5)  #s is the parameter for the size of the scattered points
plt.scatter(args_Au_BSG[0],args_Au_BSG[1], label='Au vs BSG', s=5)  #s is the parameter for the size of the scattered points
plt.plot(args_Au_Au[0], y_pred_Au_Au, label=f'slip length: {intercept_Au_Au_20ums}')
plt.plot(args_Si_BSG[0], y_pred_Si_BSG, label=f'slip length: {intercept_Si_BSG_20ums}')
plt.plot(args_Au_BSG_X1[0], y_pred_Au_BSG_X1, label=f'slip length: {intercept_Au_BSG_X1_20ums}')
plt.plot(args_Au_BSG_X3[0], y_pred_Au_BSG_X3, label=f'slip length: {intercept_Au_BSG_X3_20ums}')
plt.plot(args_Au_BSG[0], y_pred_Au_BSG, label=f'slip length: {intercept_Au_BSG_20ums}')
plt.xlabel("Separation (nm)")
plt.ylabel("Velocity/Force (nN)")
plt.legend()
#plt.xlim(0.0005, 0.002)
#plt.ylim(-1, 4000)
#plt.xlim(0.0012, 0.0016)
#plt.ylim(2851.5, 2852.5)
plt.grid()
plt.show()
print("For Au_Au")
print(f"The slope is of: {slope_Au_Au_20ums}")
print(f"The intercept is of: {intercept_Au_Au_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_Au_20ums}")
print("For Si_BSG")
print(f"The slope is of: {slope_Si_BSG_20ums}")
print(f"The intercept is of: {intercept_Si_BSG_20ums}")
print(f"The determination coefficient is of: {r_sq_Si_BSG_20ums}")
print("For Au vs BSG X1")
print(f"The slope is of: {slope_Au_BSG_X1_20ums}")
print(f"The intercept is of: {intercept_Au_BSG_X1_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X1_20ums}")
print("For Au vs BSG X3")
print(f"The slope is of: {slope_Au_BSG_X3_20ums}")
print(f"The intercept is of: {intercept_Au_BSG_X3_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_X3_20ums}")
print("For Au vs BSG")
print(f"The slope is of: {slope_Au_BSG_20ums}")
print(f"The intercept is of: {intercept_Au_BSG_20ums}")
print(f"The determination coefficient is of: {r_sq_Au_BSG_20ums}")
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\3013757437.py:23: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   a_Au_Au = np.where(aa_Au_Au < Au_Au_d_final_1800nm_20um[i][0] < bb_Au_Au)
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\3013757437.py:24: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if a_Au_Au[0] == 0:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\3013757437.py:34: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
# ...

# %% [markdown]
# ### PLOT velocity VS slip length

# %%
figure, ax = plt.subplots(2, 2,figsize=(10, 10)) 

ax[0,0].scatter(0.5,intercept_Au_Au_500nms)
ax[0,0].scatter(0.8,intercept_Au_Au_800nms)
ax[0,0].scatter(1,intercept_Au_Au_1ums)
ax[0,0].scatter(3,intercept_Au_Au_3ums)
ax[0,0].scatter(5,intercept_Au_Au_5ums)
ax[0,0].scatter(7,intercept_Au_Au_7ums)
ax[0,0].scatter(10,intercept_Au_Au_10ums)
ax[0,0].scatter(15,intercept_Au_Au_15ums)
ax[0,0].scatter(20,intercept_Au_Au_20ums)
ax[0,0].set_title("Au vs Au")
ax[0,0].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[0,0].grid()

ax[1,0].scatter(0.5,intercept_Si_BSG_500nms)
ax[1,0].scatter(0.8,intercept_Si_BSG_800nms)
ax[1,0].scatter(1,intercept_Si_BSG_1ums)
#ax[1,0].scatter(3,intercept_Si_BSG_3ums)
ax[1,0].scatter(5,intercept_Si_BSG_5ums)
ax[1,0].scatter(7,intercept_Si_BSG_7ums)
ax[1,0].scatter(10,intercept_Si_BSG_10ums)
ax[1,0].scatter(15,intercept_Si_BSG_15ums)
ax[1,0].scatter(20,intercept_Si_BSG_20ums)
ax[1,0].set_title("Si vs BSG")
ax[1,0].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[1,0].grid()

ax[0,1].scatter(0.5,intercept_Au_BSG_X1_500nms)
ax[0,1].scatter(0.8,intercept_Au_BSG_X1_800nms)
ax[0,1].scatter(1,intercept_Au_BSG_X1_1ums)
ax[0,1].scatter(3,intercept_Au_BSG_X1_3ums)
#ax[0,1].scatter(5,intercept_Au_BSG_X1_5ums)
ax[0,1].scatter(7,intercept_Au_BSG_X1_7ums)
ax[0,1].scatter(10,intercept_Au_BSG_X1_10ums)
ax[0,1].scatter(15,intercept_Au_BSG_X1_15ums)
ax[0,1].scatter(20,intercept_Au_BSG_X1_20ums)
ax[0,1].set_title("Au vs BSG (X1)")
ax[0,1].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[0,1].grid()

ax[1,1].scatter(0.5,intercept_Au_BSG_X3_500nms)
ax[1,1].scatter(0.8,intercept_Au_BSG_X3_800nms)
ax[1,1].scatter(1,intercept_Au_BSG_X3_1ums)
ax[1,1].scatter(3,intercept_Au_BSG_X3_3ums)
ax[1,1].scatter(5,intercept_Au_BSG_X3_5ums)
#ax[1,1].scatter(7,intercept_Au_BSG_X3_7ums)
ax[1,1].scatter(10,intercept_Au_BSG_X3_10ums)
ax[1,1].scatter(15,intercept_Au_BSG_X3_15ums)
ax[1,1].scatter(20,intercept_Au_BSG_X3_20ums)
ax[1,1].set_title("Au vs BSG (X3)")
ax[1,1].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[1,1].grid()

# %% [markdown]
# ### PLOT velocity vs Slip length for avg X1 and X3

# %%
figure, ax = plt.subplots(2, 2,figsize=(10, 10)) 

ax[0,0].scatter(0.5,intercept_Au_Au_500nms)
ax[0,0].scatter(0.8,intercept_Au_Au_800nms)
ax[0,0].scatter(1,intercept_Au_Au_1ums)
ax[0,0].scatter(3,intercept_Au_Au_3ums)
ax[0,0].scatter(5,intercept_Au_Au_5ums)
ax[0,0].scatter(7,intercept_Au_Au_7ums)
ax[0,0].scatter(10,intercept_Au_Au_10ums)
ax[0,0].scatter(15,intercept_Au_Au_15ums)
ax[0,0].scatter(20,intercept_Au_Au_20ums)
ax[0,0].set_title("Au vs Au")
ax[0,0].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[0,0].set_xlim(-2,22)
ax[0,0].set_ylim(-22,2)
ax[0,0].grid()

ax[1,0].scatter(0.5,intercept_Si_BSG_500nms)
ax[1,0].scatter(0.8,intercept_Si_BSG_800nms)
ax[1,0].scatter(1,intercept_Si_BSG_1ums)
#ax[1,0].scatter(3,intercept_Si_BSG_3ums)
ax[1,0].scatter(5,intercept_Si_BSG_5ums)
ax[1,0].scatter(7,intercept_Si_BSG_7ums)
ax[1,0].scatter(10,intercept_Si_BSG_10ums)
ax[1,0].scatter(15,intercept_Si_BSG_15ums)
ax[1,0].scatter(20,intercept_Si_BSG_20ums)
ax[1,0].set_title("Si vs BSG")
ax[1,0].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[1,0].set_xlim(-2,22)
ax[1,0].set_ylim(-22,2)
ax[1,0].grid()

ax[0,1].scatter(0.5,intercept_Au_BSG_500nms)
ax[0,1].scatter(0.8,intercept_Au_BSG_800nms)
ax[0,1].scatter(1,intercept_Au_BSG_1ums)
ax[0,1].scatter(3,intercept_Au_BSG_3ums)
#ax[0,1].scatter(5,intercept_Au_BSG_5ums)
#ax[0,1].scatter(7,intercept_Au_BSG_7ums)
ax[0,1].scatter(10,intercept_Au_BSG_10ums)
ax[0,1].scatter(15,intercept_Au_BSG_15ums)
ax[0,1].scatter(20,intercept_Au_BSG_20ums)
ax[0,1].set_title("Au vs BSG")
ax[0,1].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[0,1].set_xlim(-2,22)
ax[0,1].set_ylim(-22,2)
ax[0,1].grid()

Constant = 3
def inversefunc(Constant,x):
    return Constant/(-x)
x = np.arange(0,22,0.005)
ax[1,1].scatter(x,inversefunc(Constant,x), s=0.7, label = f'Constant = {Constant}')
ax[1,1].set_title("Possible plot of Constant/-velocity")
ax[1,1].set(xlabel='Velocity (um/s)', ylabel='Slip length (nm)')
ax[1,1].set_xlim(-2,22)
ax[1,1].set_ylim(-22,2)
ax[1,1].legend()
ax[1,1].grid()

plt.show()
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_31204\2688027152.py:50: RuntimeWarning: divide by zero encountered in divide
#   return Constant/(-x)

# %% [markdown]
# ### PLOT slip length VS setup

# %%
figure, ax = plt.subplots(3, 3,figsize=(15, 15)) 

ax[0,0].scatter("Au vs Au",intercept_Au_Au_500nms,label='Au vs Au')
ax[0,0].scatter("Si vs BSG",intercept_Si_BSG_500nms,label='Si vs BSG')
ax[0,0].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_500nms,label='Au vs BSG (X1)')
ax[0,0].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_500nms,label='Au vs BSG (X3)')
ax[0,0].set_title("500nm/s")
ax[0,0].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[0,0].legend()
ax[0,0].grid()

ax[0,1].scatter("Au vs Au",intercept_Au_Au_800nms,label='Au vs Au')
ax[0,1].scatter("Si vs BSG",intercept_Si_BSG_800nms,label='Si vs BSG')
ax[0,1].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_800nms,label='Au vs BSG (X1)')
ax[0,1].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_800nms,label='Au vs BSG (X3)')
ax[0,1].set_title("800nm/s")
ax[0,1].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[0,1].legend()
ax[0,1].grid()

ax[0,2].scatter("Au vs Au",intercept_Au_Au_1ums,label='Au vs Au')
ax[0,2].scatter("Si vs BSG",intercept_Si_BSG_1ums,label='Si vs BSG')
ax[0,2].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_1ums,label='Au vs BSG (X1)')
ax[0,2].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_1ums,label='Au vs BSG (X3)')
ax[0,2].set_title("1um/s")
ax[0,2].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[0,2].legend()
ax[0,2].grid()

ax[1,0].scatter("Au vs Au",intercept_Au_Au_3ums,label='Au vs Au')
#ax[1,0].scatter("Si vs BSG",intercept_Si_BSG_3ums,label='Si vs BSG')
ax[1,0].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_3ums,label='Au vs BSG (X1)')
ax[1,0].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_3ums,label='Au vs BSG (X3)')
ax[1,0].set_title("3um/s")
ax[1,0].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[1,0].legend()
ax[1,0].grid()

ax[1,1].scatter("Au vs Au",intercept_Au_Au_5ums,label='Au vs Au')
ax[1,1].scatter("Si vs BSG",intercept_Si_BSG_5ums,label='Si vs BSG')
#ax[1,1].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_5ums,label='Au vs BSG (X1)')
ax[1,1].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_5ums,label='Au vs BSG (X3)')
ax[1,1].set_title("5um/s")
ax[1,1].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[1,1].legend()
ax[1,1].grid()

ax[1,2].scatter("Au vs Au",intercept_Au_Au_7ums,label='Au vs Au')
ax[1,2].scatter("Si vs BSG",intercept_Si_BSG_7ums,label='Si vs BSG')
ax[1,2].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_7ums,label='Au vs BSG (X1)')
#ax[1,2].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_7ums,label='Au vs BSG (X3)')
ax[1,2].set_title("7um/s")
ax[1,2].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[1,2].legend()
ax[1,2].grid()

ax[2,0].scatter("Au vs Au",intercept_Au_Au_10ums,label='Au vs Au')
ax[2,0].scatter("Si vs BSG",intercept_Si_BSG_10ums,label='Si vs BSG')
ax[2,0].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_10ums,label='Au vs BSG (X1)')
ax[2,0].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_10ums,label='Au vs BSG (X3)')
ax[2,0].set_title("10um/s")
ax[2,0].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[2,0].legend()
ax[2,0].grid()

ax[2,1].scatter("Au vs Au",intercept_Au_Au_15ums,label='Au vs Au')
ax[2,1].scatter("Si vs BSG",intercept_Si_BSG_15ums,label='Si vs BSG')
ax[2,1].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_15ums,label='Au vs BSG (X1)')
ax[2,1].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_15ums,label='Au vs BSG (X3)')
ax[2,1].set_title("15um/s")
ax[2,1].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[2,1].legend()
ax[2,1].grid()

ax[2,2].scatter("Au vs Au",intercept_Au_Au_20ums,label='Au vs Au')
ax[2,2].scatter("Si vs BSG",intercept_Si_BSG_20ums,label='Si vs BSG')
ax[2,2].scatter("Au vs BSG (X1)",intercept_Au_BSG_X1_20ums,label='Au vs BSG (X1)')
ax[2,2].scatter("Au vs BSG (X3)",intercept_Au_BSG_X3_20ums,label='Au vs BSG (X3)')
ax[2,2].set_title("20um/s")
ax[2,2].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[2,2].legend()
ax[2,2].grid()


plt.show()

# %% [markdown]
# ### PLOT slip length vs setup for average of X1 and X3

# %%
figure, ax = plt.subplots(3, 3,figsize=(15, 15)) 

ax[0,0].scatter("Au vs Au",intercept_Au_Au_500nms,color='royalblue',label='Au vs Au')
ax[0,0].scatter("Si vs BSG",intercept_Si_BSG_500nms,color='red',label='Si vs BSG')
ax[0,0].scatter("Au vs BSG",intercept_Au_BSG_500nms,color='darkorange',label='Au vs BSG')
ax[0,0].set_title("500nm/s")
ax[0,0].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[0,0].legend()
ax[0,0].grid()

ax[0,1].scatter("Au vs Au",intercept_Au_Au_800nms,color='royalblue',label='Au vs Au')
ax[0,1].scatter("Si vs BSG",intercept_Si_BSG_800nms,color='red',label='Si vs BSG')
ax[0,1].scatter("Au vs BSG",intercept_Au_BSG_800nms,color='darkorange',label='Au vs BSG')
ax[0,1].set_title("800nm/s")
ax[0,1].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[0,1].legend()
ax[0,1].grid()

ax[0,2].scatter("Au vs Au",intercept_Au_Au_1ums,color='royalblue',label='Au vs Au')
ax[0,2].scatter("Si vs BSG",intercept_Si_BSG_1ums,color='red',label='Si vs BSG')
ax[0,2].scatter("Au vs BSG",intercept_Au_BSG_1ums,color='darkorange',label='Au vs BSG')
ax[0,2].set_title("1um/s")
ax[0,2].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[0,2].legend()
ax[0,2].grid()

ax[1,0].scatter("Au vs Au",intercept_Au_Au_3ums,color='royalblue',label='Au vs Au')
#ax[1,0].scatter("Si vs BSG",intercept_Si_BSG_3ums,color='red',label='Si vs BSG')
ax[1,0].scatter("Au vs BSG",intercept_Au_BSG_3ums,color='darkorange',label='Au vs BSG')
ax[1,0].set_title("3um/s")
ax[1,0].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[1,0].legend()
ax[1,0].grid()

ax[1,1].scatter("Au vs Au",intercept_Au_Au_5ums,color='royalblue',label='Au vs Au')
ax[1,1].scatter("Si vs BSG",intercept_Si_BSG_5ums,color='red',label='Si vs BSG')
ax[1,1].set_title("5um/s")
ax[1,1].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[1,1].legend()
ax[1,1].grid()

ax[1,2].scatter("Au vs Au",intercept_Au_Au_7ums,color='royalblue',label='Au vs Au')
ax[1,2].scatter("Si vs BSG",intercept_Si_BSG_7ums,color='red',label='Si vs BSG')
ax[1,2].set_title("7um/s")
ax[1,2].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[1,2].legend()
ax[1,2].grid()

ax[2,0].scatter("Au vs Au",intercept_Au_Au_10ums,color='royalblue',label='Au vs Au')
ax[2,0].scatter("Si vs BSG",intercept_Si_BSG_10ums,color='red',label='Si vs BSG')
ax[2,0].scatter("Au vs BSG",intercept_Au_BSG_10ums,color='darkorange',label='Au vs BSG')
ax[2,0].set_title("10um/s")
ax[2,0].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[2,0].legend()
ax[2,0].grid()

ax[2,1].scatter("Au vs Au",intercept_Au_Au_15ums,color='royalblue',label='Au vs Au')
ax[2,1].scatter("Si vs BSG",intercept_Si_BSG_15ums,color='red',label='Si vs BSG')
ax[2,1].scatter("Au vs BSG",intercept_Au_BSG_15ums,color='darkorange',label='Au vs BSG')
ax[2,1].set_title("15um/s")
ax[2,1].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[2,1].legend()
ax[2,1].grid()

ax[2,2].scatter("Au vs Au",intercept_Au_Au_20ums,color='royalblue',label='Au vs Au')
ax[2,2].scatter("Si vs BSG",intercept_Si_BSG_20ums,color='red',label='Si vs BSG')
ax[2,2].scatter("Au vs BSG",intercept_Au_BSG_20ums,color='darkorange',label='Au vs BSG')
ax[2,2].set_title("20um/s")
ax[2,2].set(xlabel='Setup', ylabel='Slip length (nm)')
ax[2,2].legend()
ax[2,2].grid()


plt.show()

# %% [markdown]
# ### Export final slip lenghts

# %%
Nothing = 0
Intercepts_Au_Au = [Nothing,intercept_Au_Au_500nms,intercept_Au_Au_800nms,intercept_Au_Au_1ums,intercept_Au_Au_3ums,intercept_Au_Au_5ums,intercept_Au_Au_7ums,intercept_Au_Au_10ums,intercept_Au_Au_15ums,intercept_Au_Au_20ums]
np.savetxt('Intercepts_Au_Au.csv', Intercepts_Au_Au, delimiter=',')

Intercepts_Si_BSG = [Nothing,intercept_Si_BSG_500nms,intercept_Si_BSG_800nms,intercept_Si_BSG_1ums,Nothing,intercept_Si_BSG_5ums,intercept_Si_BSG_7ums,intercept_Si_BSG_10ums,intercept_Si_BSG_15ums,intercept_Si_BSG_20ums]
np.savetxt('Intercepts_Si_BSG.csv', Intercepts_Si_BSG, delimiter=',')

Intercepts_Au_BSG = [Nothing,intercept_Au_BSG_500nms,intercept_Au_BSG_800nms,intercept_Au_BSG_1ums,intercept_Au_BSG_3ums,Nothing,Nothing,intercept_Au_BSG_10ums,intercept_Au_BSG_15ums,intercept_Au_BSG_20ums]
np.savetxt('Intercepts_Au_BSG.csv', Intercepts_Au_BSG, delimiter=',')

Intercepts_Au_BSG_X1 = [Nothing,intercept_Au_BSG_X1_500nms,intercept_Au_BSG_X1_800nms,intercept_Au_BSG_X1_1ums,intercept_Au_BSG_X1_3ums,Nothing,intercept_Au_BSG_X1_7ums,intercept_Au_BSG_X1_10ums,intercept_Au_BSG_X1_15ums,intercept_Au_BSG_X1_20ums]
np.savetxt('Intercepts_Au_BSG_X1.csv', Intercepts_Au_BSG_X1, delimiter=',')

Intercepts_Au_BSG_X3 = [Nothing,intercept_Au_BSG_X3_500nms,intercept_Au_BSG_X3_800nms,intercept_Au_BSG_X3_1ums,intercept_Au_BSG_X3_3ums,intercept_Au_BSG_X3_5ums,Nothing,intercept_Au_BSG_X3_10ums,intercept_Au_BSG_X3_15ums,intercept_Au_BSG_X3_20ums]
np.savetxt('Intercepts_Au_BSG_X3.csv', Intercepts_Au_BSG_X3, delimiter=',')

# %% [markdown]
# ### Export CHINESE slip lengths

# %%
Nothing = 0
Intercepts_Au_Au = [Nothing,30.445,24.35,24.58,23.77,22.14,22.1,6.695,16.4,40.4]
np.savetxt('Intercepts_Au_Au_chinese_paper.csv', Intercepts_Au_Au, delimiter=',')

Intercepts_Si_BSG = [Nothing,27.76,26.8,27.22,Nothing,29.8,39.5,49.2,62.5,38.91]
np.savetxt('Intercepts_Si_BSG_chinese_paper.csv', Intercepts_Si_BSG, delimiter=',')

Intercepts_Au_BSG = [Nothing,32.0,43.24,39.25,27.6,Nothing,Nothing,36.5,38.2,33.38]
np.savetxt('Intercepts_Au_BSG_chinese_paper.csv', Intercepts_Au_BSG, delimiter=',')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
